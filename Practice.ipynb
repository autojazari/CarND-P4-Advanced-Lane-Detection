# %%
import numpy as np
import cv2
import glob
import matplotlib.pyplot as plt
from moviepy.editor import VideoFileClip
from IPython.display import HTML

# %matplotlib inline

# undistort
# some threshold (on grayscale and/or color and/or HLS)
# transform
# sliding window
# detect lines
# draw lines over the transformed image
# reverse transform

# %%
class LaneDetection(object):
    
    def __init__(self, cal_images, test_image, input_video_file, output_video_file):
        
        self.count = 0
        
        self.cal_images = cal_images
        
        # calibrate the camera with the test image
        self.calibrate_camera(cv2.imread(test_image))
        
        # create a video reader
        self.reader = cv2.VideoCapture(input_video_file)
        
        # read first frame to get dimensions
        self.ret, self.first_frame = self.reader.read()
        
        if self.ret:
            self.writer = cv2.VideoWriter(output_video_file, cv2.VideoWriter_fourcc(*"H264"), 25, self.first_frame.shape[:2], False)
        else:
            raise RuntimeError("OK")
    
    def set_obj_and_img_points(self):
        # prepare object points, like (0,0,0), (1,0,0), (2,0,0) ....,(6,5,0)
        objp = np.zeros((6*9,3), np.float32)
        objp[:,:2] = np.mgrid[0:9,0:6].T.reshape(-1,2)

        # Arrays to store object points and image points from all the images.
        self.objpoints = [] # 3d points in real world space
        self.imgpoints = [] # 2d points in image plane.
    
        # Step through the list and search for chessboard corners
        for fname in self.cal_images:
            img = cv2.imread(fname)
            gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

            # Find the chessboard corners
            ret, corners = cv2.findChessboardCorners(gray, (9, 6), None)
#             if not ret: print(fname)
            # If found, add object points, image points
            if ret == True:
                self.objpoints.append(objp)
                self.imgpoints.append(corners)

                # Draw and display the corners
                img = cv2.drawChessboardCorners(img, (9,6), corners, ret)
    
    def calibrate_camera(self, test_image):
        img_size = (test_image.shape[1], test_image.shape[0])
        
        self.set_obj_and_img_points()
        
        if len(self.objpoints) == 0 or len(self.imgpoints) == 0:
            raise Exception("Calibration Failed!")
        
        # Do camera calibration given object points and image points
        ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(self.objpoints, self.imgpoints, img_size, None, None)
        
        self.mtx = mtx
        self.dist = dist

    def undistort(self, img):
        return cv2.undistort(img, self.mtx, self.dist, None, self.mtx)
    
    def to_gray(self, img):
        return cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    def to_rgb(self, img):
        return cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        
    def abs_sobel_thresh(self, gray, orient='x', thresh_min=40, thresh_max=200, ksize=5):
        # Apply x or y gradient with the OpenCV Sobel() function
        # and take the absolute value
        if orient == 'x':
            abs_sobel = np.absolute(cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=ksize))
        if orient == 'y':
            abs_sobel = np.absolute(cv2.Sobel(gray, cv2.CV_64F, 0, 1, ksize=ksize))
        
        # Rescale back to 8 bit integer
        scaled_sobel = np.uint8(255 * abs_sobel / np.max(abs_sobel))
        
        # Create a copy and apply the threshold
        binary_output = np.zeros_like(scaled_sobel)
        
        binary_output[(scaled_sobel >= thresh_min) & (scaled_sobel <= thresh_max)] = 1

        # Return the result
        return binary_output
    
    def mag_thresh(self, gray, thresh_min=40, thresh_max=250, ksize=7):
        # Take both Sobel x and y gradients
        sobelx = cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=ksize)
        
        sobely = cv2.Sobel(gray, cv2.CV_64F, 0, 1, ksize=ksize)
        
        # Calculate the gradient magnitude
        gradmag = np.sqrt(sobelx**2 + sobely**2)
        
        # Rescale to 8 bit
        scale_factor = np.max(gradmag) / 255 
        
        gradmag = (gradmag/scale_factor).astype(np.uint8) 
        
        # Create a binary image of ones where threshold is met, zeros otherwise
        binary_output = np.zeros_like(gradmag)
        
        binary_output[(gradmag >= thresh_min) & (gradmag <= thresh_max)] = 1

        # Return the binary image
        return binary_output
    
    def dir_threshold(self, gray, ksize=7, thresh=(0.7, 1.3)):

        # Calculate the x and y gradients
        sobelx = cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=ksize)
        
        sobely = cv2.Sobel(gray, cv2.CV_64F, 0, 1, ksize=ksize)
        
        # Take the absolute value of the gradient direction, 
        # apply a threshold, and create a binary image result
        absgraddir = np.arctan2(np.absolute(sobely), np.absolute(sobelx))
        
        binary_output =  np.zeros_like(absgraddir)
        
        binary_output[(absgraddir >= thresh[0]) & (absgraddir <= thresh[1])] = 1

        # Return the binary image
        return binary_output
    
    def gradient_binary(self, gray, thresh_min=40, thresh_max=250, ksize=7, thresh=(0.7, 1.3)):
        # Apply each of the thresholding functions
        gradx = self.abs_sobel_thresh(gray, orient='x',thresh_min=thresh_min, thresh_max=thresh_max, ksize=ksize)

        grady = self.abs_sobel_thresh(gray, orient='y', thresh_min=thresh_min, thresh_max=thresh_max, ksize=ksize)

        mag_binary = self.mag_thresh(gray, thresh_min=thresh_min, thresh_max=thresh_max, ksize=ksize)

        dir_binary = self.dir_threshold(gray, ksize=ksize, thresh=thresh)
        
        combined = np.zeros_like(dir_binary)
        
        combined[((gradx == 1) & (grady == 1)) | ((mag_binary == 1) & (dir_binary == 1))] = 1
        
        # Return the result
        return combined
        
    def binary_transform(self, img, thresh_min=40, thresh_max=250, ksize=7, thresh=(0.7, 1.3), hls_thresh=(175, 255)):
        
        gray = self.to_gray(img)
        
        # Threshold gradient
        sxbinary = self.gradient_binary(gray, thresh_min=thresh_min, thresh_max=thresh_max, ksize=ksize, thresh=thresh)
    
        # Threshold color channel
        s_binary = self.to_hls(img)
    
        # Stack each channel to view their individual contributions in green and blue respectively
        # This returns a stack of the two binary images, whose components you can see as different colors
        color_binary = np.dstack(( np.zeros_like(sxbinary), sxbinary, s_binary))
    
        # Combine the two binary thresholds
        combined_binary = np.zeros_like(sxbinary)
        combined_binary[(s_binary == 1) | (sxbinary == 1)] = 1
        
        # Return the result
        return sxbinary
    
    def to_hls(self, img, hls_thresh=(50, 200)):
        hls = cv2.cvtColor(img, cv2.COLOR_BGR2HLS)
        
        s_channel = hls[:,:,2]
        
        binary_output = np.zeros_like(s_channel)
        
        binary_output[(s_channel > hls_thresh[0]) & (s_channel <= hls_thresh[1])] = 1
        
        return binary_output
    
    def perspective_transform(self, binary):
        self.img_size = (binary.shape[1], binary.shape[0])

        self.src = np.float32(
            [[(self.img_size[0] / 2) - 55, self.img_size[1] / 2 + 100],
            [((self.img_size[0] / 6) - 10), self.img_size[1]],
            [(self.img_size[0] * 5 / 6) + 60, self.img_size[1]],
            [(self.img_size[0] / 2 + 55), self.img_size[1] / 2 + 100]])

        self.dst = np.float32(
            [[(self.img_size[0] / 4), 0],
            [(self.img_size[0] / 4), self.img_size[1]],
            [(self.img_size[0] * 3 / 4), self.img_size[1]],
            [(self.img_size[0] * 3 / 4), 0]])

#         self.src = np.float32([
#             [  585., 460.],
#             [  286 , 675.],
#             [ 1005 , 675.],
#             [  695., 460.]])
    
#         self.dst = np.float32([
#             [ 320.,    0.],
#             [ 320.,  720.],
#             [ 960.,  720.],
#             [ 960.,    0.]])


        
#         vertices = np.float32(
#             [[(105, .888*imshape[0]), (.333*imshape[1],
#             .708*imshape[0]),
#         (.528*imshape[1],
#             .597*imshape[0]),
#         (imshape[1], .805*imshape[0])]], dtype=np.int32)
        
        # Given src and dst points, calculate the perspective transform matrix
        M = cv2.getPerspectiveTransform(self.src, self.dst)
        # Warp the image using OpenCV warpPerspective()
        return cv2.warpPerspective(binary, M, self.img_size)
    
    def detect_lines_first_frame(self, binary_warped):
        # Assuming you have created a warped binary image called "binary_warped"
        # Take a histogram of the bottom half of the image
        histogram = np.sum(binary_warped[binary_warped.shape[0]/2:,:], axis=0)
        
        # Create an output image to draw on and  visualize the result
        out_img = np.dstack((binary_warped, binary_warped, binary_warped))*255
    
        # Find the peak of the left and right halves of the histogram
        # These will be the starting point for the left and right lines
        midpoint = np.int(histogram.shape[0]/2)

        leftx_base = np.argmax(histogram[:midpoint])

        rightx_base = np.argmax(histogram[midpoint:]) + midpoint

        # Choose the number of sliding windows
        nwindows = 9
        
        # Set height of windows
        window_height = np.int(binary_warped.shape[0]/nwindows)
        
        # Identify the x and y positions of all nonzero pixels in the image
        nonzero = binary_warped.nonzero()
        nonzeroy = np.array(nonzero[0])
        nonzerox = np.array(nonzero[1])
    
        # Current positions to be updated for each window
        leftx_current = leftx_base
        rightx_current = rightx_base
        
        # Set the width of the windows +/- margin
        margin = 100
        
        # Set minimum number of pixels found to recenter window
        minpix = 50
        
        # Create empty lists to receive left and right lane pixel indices
        left_lane_inds = []
        right_lane_inds = []

        # Step through the windows one by one
        for window in range(nwindows):
            # Identify window boundaries in x and y (and right and left)
            win_y_low = binary_warped.shape[0] - (window + 1) * window_height
            
            win_y_high = binary_warped.shape[0] - window * window_height
            
            win_xleft_low = leftx_current - margin
            
            win_xleft_high = leftx_current + margin
            
            win_xright_low = rightx_current - margin
            
            win_xright_high = rightx_current + margin
            # Draw the windows on the visualization image
            
            cv2.rectangle(out_img, (win_xleft_low, win_y_low),(win_xleft_high, win_y_high), (0, 255, 0), 2) 
            
            cv2.rectangle(out_img, (win_xright_low, win_y_low),(win_xright_high, win_y_high), (0, 255, 0), 2) 
            
            # Identify the nonzero pixels in x and y within the window
            good_left_inds = ((nonzeroy >= win_y_low) & (nonzeroy < win_y_high) & (nonzerox >= win_xleft_low) & (nonzerox < win_xleft_high)).nonzero()[0]
            
            good_right_inds = ((nonzeroy >= win_y_low) & (nonzeroy < win_y_high) & (nonzerox >= win_xright_low) & (nonzerox < win_xright_high)).nonzero()[0]
            
            # Append these indices to the lists
            left_lane_inds.append(good_left_inds)
            
            right_lane_inds.append(good_right_inds)
            
            # If you found > minpix pixels, recenter next window on their mean position
            if len(good_left_inds) > minpix:
                leftx_current = np.int(np.mean(nonzerox[good_left_inds]))
            if len(good_right_inds) > minpix:        
                rightx_current = np.int(np.mean(nonzerox[good_right_inds]))

        # Concatenate the arrays of indices
        left_lane_inds = np.concatenate(left_lane_inds)
            
        right_lane_inds = np.concatenate(right_lane_inds)
          
            
#         print(left_lane_inds, right_lane_inds)

        # Extract left and right line pixel positions
        leftx = nonzerox[left_lane_inds]
            
        lefty = nonzeroy[left_lane_inds] 
            
        rightx = nonzerox[right_lane_inds]
            
        righty = nonzeroy[right_lane_inds] 

        # Fit a second order polynomial to each
        self.left_fit = np.polyfit(lefty, leftx, 2)
            
        self.right_fit = np.polyfit(righty, rightx, 2)
        
        print(len(self.left_fit), len(self.right_fit))
        
        ploty = np.linspace(0, binary_warped.shape[0]-1, binary_warped.shape[0])
        y_eval = np.max(ploty)
        
        # Define conversions in x and y from pixels space to meters
        ym_per_pix = 30 / 720 # meters per pixel in y dimension
        xm_per_pix = 3.7 / 700 # meters per pixel in x dimension
    
        # Fit new polynomials to x,y in world space
        left_fit_cr = np.polyfit(lefty * ym_per_pix, leftx * xm_per_pix, 2)
        right_fit_cr = np.polyfit(righty * ym_per_pix, rightx * xm_per_pix, 2)
        
        # Calculate the new radii of curvature
        left_curverad = ((1 + (2*left_fit_cr[0]*y_eval*ym_per_pix + left_fit_cr[1])**2)**1.5) / np.absolute(2*left_fit_cr[0])
        right_curverad = ((1 + (2*right_fit_cr[0]*y_eval*ym_per_pix + right_fit_cr[1])**2)**1.5) / np.absolute(2*right_fit_cr[0])
        # Now our radius of curvature is in meters
        print(left_curverad*3.28084, 'ft', right_curverad*3.28084, 'ft')
        print(left_curverad, 'm', right_curverad, 'm')
#         Example values: 632.1 m    626.2 m
        
#         raise RuntimeError("OK")
            
        # This is ONLY for plotting
        # Generate x and y values for plotting
#         ploty = np.linspace(0, binary_warped.shape[0]-1, binary_warped.shape[0] )
#         left_fitx = self.left_fit[0]*ploty**2 + self.left_fit[1]*ploty + self.left_fit[2]
#         right_fitx = self.right_fit[0]*ploty**2 + self.right_fit[1]*ploty + self.right_fit[2]

#         out_img[nonzeroy[left_lane_inds], nonzerox[left_lane_inds]] = [255, 0, 0]
#         out_img[nonzeroy[right_lane_inds], nonzerox[right_lane_inds]] = [0, 0, 255]
#         plt.imshow(out_img)
#         plt.plot(left_fitx, ploty, color='yellow')
#         plt.plot(right_fitx, ploty, color='yellow')
#         plt.xlim(0, 1280)
#         plt.ylim(720, 0)
        
    def detect_lines(self, binary_warped, orgin):
        # Assume you now have a new warped binary image 
        # from the next frame of video (also called "binary_warped")
        # It's now much easier to find line pixels!
        nonzero = binary_warped.nonzero()
        nonzeroy = np.array(nonzero[0])
        nonzerox = np.array(nonzero[1])
        margin = 100
        left_lane_inds = ((nonzerox > (self.left_fit[0]*(nonzeroy**2) + self.left_fit[1]*nonzeroy + self.left_fit[2] - margin)) & (nonzerox < (self.left_fit[0]*(nonzeroy**2) + self.left_fit[1]*nonzeroy + self.left_fit[2] + margin))) 
        right_lane_inds = ((nonzerox > (self.right_fit[0]*(nonzeroy**2) + self.right_fit[1]*nonzeroy + self.right_fit[2] - margin)) & (nonzerox < (self.right_fit[0]*(nonzeroy**2) + self.right_fit[1]*nonzeroy + self.right_fit[2] + margin)))  

        # Again, extract left and right line pixel positions
        leftx = nonzerox[left_lane_inds]
        lefty = nonzeroy[left_lane_inds] 
        rightx = nonzerox[right_lane_inds]
        righty = nonzeroy[right_lane_inds]
        # Fit a second order polynomial to each
        self.left_fit = np.polyfit(lefty, leftx, 2)
        self.right_fit = np.polyfit(righty, rightx, 2)
        
        # Generate x and y values for plotting
        ploty = np.linspace(0, binary_warped.shape[0]-1, binary_warped.shape[0])
        left_fitx = self.left_fit[0] * ploty**2 + self.left_fit[1] * ploty + self.left_fit[2]
        right_fitx = self.right_fit[0] * ploty**2 + self.right_fit[1] * ploty + self.right_fit[2]

         # Create an image to draw on and an image to show the selection window
        out_img = np.dstack((binary_warped, binary_warped, binary_warped))*255

        window_img = np.zeros_like(out_img)

        # Color in left and right line pixels
        out_img[nonzeroy[left_lane_inds], nonzerox[left_lane_inds]] = [255, 0, 0]
        out_img[nonzeroy[right_lane_inds], nonzerox[right_lane_inds]] = [0, 0, 255]

        # Generate a polygon to illustrate the search window area
        # And recast the x and y points into usable format for cv2.fillPoly()
        left_line_window1 = np.array([np.transpose(np.vstack([left_fitx-margin, ploty]))])
        left_line_window2 = np.array([np.flipud(np.transpose(np.vstack([left_fitx+margin, ploty])))])
        left_line_pts = np.hstack((left_line_window1, left_line_window2))
        
        right_line_window1 = np.array([np.transpose(np.vstack([right_fitx-margin, ploty]))])
        right_line_window2 = np.array([np.flipud(np.transpose(np.vstack([right_fitx+margin, ploty])))])
        right_line_pts = np.hstack((right_line_window1, right_line_window2))

        # Draw the lane onto the warped blank image
#         cv2.fillPoly(window_img, np.int_([left_line_pts]), (0,255, 0))
#         cv2.fillPoly(window_img, np.int_([right_line_pts]), (0,255, 0))
#         result = cv2.addWeighted(out_img, 1, window_img, 0.3, 0)
#         plt.imshow(result)
#         plt.plot(left_fitx, ploty, color='yellow')
#         plt.plot(right_fitx, ploty, color='yellow')
#         plt.xlim(0, 1280)
#         plt.ylim(720, 0)
        
        y_eval = np.max(ploty)
        
        # Define conversions in x and y from pixels space to meters
        ym_per_pix = 30 / 720 # meters per pixel in y dimension
        xm_per_pix = 3.7 / 700 # meters per pixel in x dimension
    
        # Fit new polynomials to x,y in world space
        left_fit_cr = np.polyfit(lefty * ym_per_pix, leftx * xm_per_pix, 2)
        right_fit_cr = np.polyfit(righty * ym_per_pix, rightx * xm_per_pix, 2)
        
        # Calculate the new radii of curvature
        left_curverad = ((1 + (2*left_fit_cr[0]*y_eval*ym_per_pix + left_fit_cr[1])**2)**1.5) / np.absolute(2*left_fit_cr[0])
        right_curverad = ((1 + (2*right_fit_cr[0]*y_eval*ym_per_pix + right_fit_cr[1])**2)**1.5) / np.absolute(2*right_fit_cr[0])
        # Now our radius of curvature is in meters
#         print(left_curverad*3.28084, 'ft', right_curverad*3.28084, 'ft')
#         print(left_curverad, 'm', right_curverad, 'm')
#         Example values: 632.1 m    626.2 m

        # Create an image to draw the lines on
        warp_zero = np.zeros_like(binary_warped).astype(np.uint8)
        color_warp = np.dstack((warp_zero, warp_zero, warp_zero))

        # Recast the x and y points into usable format for cv2.fillPoly()
        pts_left = np.array([np.transpose(np.vstack([left_fitx, ploty]))])
        pts_right = np.array([np.flipud(np.transpose(np.vstack([right_fitx, ploty])))])
        pts = np.hstack((pts_left, pts_right))

        # Draw the lane onto the warped blank image
        cv2.fillPoly(color_warp, np.int_([pts]), (0,255, 0))

        Minv = cv2.getPerspectiveTransform(self.dst, self.src)
        
        # Warp the blank back to original image space using inverse perspective matrix (Minv)
        newwarp = cv2.warpPerspective(color_warp, Minv, self.img_size) 
        # Combine the result with the original image
        result = cv2.addWeighted(orgin, 1, newwarp, 0.3, 0)
        plt.imshow(self.to_rgb(result))
        cv2.imwrite('./output_images/lanes_detected{}.jpg'.format(self.count), result)
#         cv2.imshow('frame',result)
        self.writer.write(result)
        return result

    def process_image(self, img):
        if self.count == 0:
            self.count += 1
            binary = ld.binary_transform(ld.undistort(img), thresh_min=40, thresh_max=200, ksize=3, thresh=(0.7, 1.3), hls_thresh=(175, 255))
            
            binary_warped = ld.perspective_transform(binary)
            
            return self.detect_lines_first_frame(binary_warped)
        
        
        binary = ld.binary_transform(ld.undistort(img), thresh_min=40, thresh_max=200, ksize=3, thresh=(0.7, 1.3), hls_thresh=(175, 255))

        binary_warped = ld.perspective_transform(binary)
        
        self.count += 1
        
        return self.detect_lines(binary_warped, img)

# %%
images = glob.glob('camera_cal/calibration*.jpg')
test_image = images.pop(-1)
ld = LaneDetection(images, test_image, 'project_video.mp4', 'output_video.mp4')

# %%
img = cv2.imread('project_video_export/frame1.jpg')
binary = ld.binary_transform(ld.undistort(img), thresh_min=40, thresh_max=200, ksize=3, thresh=(0.7, 1.3), hls_thresh=(175, 255))
binary_warped = ld.perspective_transform(binary)
ld.detect_lines_first_frame(binary_warped)
# cv2.imwrite('wrong.jpg', binary*255)
plt.imshow(binary_warped)

# %%
import numpy as np
import cv2
import glob

# Define a class to receive the characteristics of each line detection


class Line(object):

    def __init__(self):
        # was the line detected in the last iteration?
        self.detected = False

        # x values of the last n fits of the line
        self.recent_xfitted = []

        # average x values of the fitted line over the last n iterations
        self.bestx = None

        # store all polynomials to use in best_fit
        self.polyfits = []

        # polynomial coefficients averaged over the last n iterations
        self.best_fit = None

        # polynomial coefficients for the most recent fit
        self.current_fit = [np.array([False])]

        # radius of curvature of the line in meters
        self.radius_of_curvature = None

        # distance in meters of vehicle center from the line
        self.line_base_pos = None

        # difference in fit coefficients between last and new fits
        self.diffs = np.array([0, 0, 0], dtype='float')

        # x values for detected line pixels
        self.x = []

        # y values for detected line pixels
        self.y = []

        # indices of the lane segment
        self.inds = []

    def average_fit(self):
        self.best_fit = np.mean(self.polyfits, axis=0)


class LaneDetection(object):

    def __init__(self, cal_images, test_image, input_video_file, output_video_file):
        # number of frames in video
        self.count = -1

        # the number of sliding windows
        self.nwindows = 9

        # Set the width of the windows +/- self.margin
        self.margin = 100

        # Set minimum number of pixels found to recenter window
        self.minpix = 50

        # calibration image
        self.cal_images = cal_images

        # calibrate the camera with the test image
        self.calibrate_camera(cv2.imread(test_image))

        # create a video reader
        self.reader = cv2.VideoCapture(input_video_file)

        # read first frame to get dimensions
        self.ret, self.first_frame = self.reader.read()

        # Define conversions in x and y from pixels space to meters
        self.ym_per_pix = 30 / 720  # meters per pixel in y dimension

        self.xm_per_pix = 3.7 / 700  # meters per pixel in x dimension

        # pixel to meter conversion
        self.pix_to_meter = 0.0002636

        # left line data
        self.left_line = Line()

        # right line data
        self.right_line = Line()

        if self.ret:
            # video writer
            self.writer = cv2.VideoWriter(output_video_file,
                                          cv2.VideoWriter_fourcc(*"H264"),
                                          25,
                                          self.first_frame.shape[:2], False)

    def set_obj_and_img_points(self):
        # prepare object points, like (0,0,0), (1,0,0), (2,0,0) ....,(6,5,0)
        objp = np.zeros((6 * 9, 3), np.float32)
        objp[:, :2] = np.mgrid[0:9, 0:6].T.reshape(-1, 2)

        # Arrays to store object points and image points from all the images.
        self.objpoints = []  # 3d points in real world space
        self.imgpoints = []  # 2d points in image plane.

        # Step through the list and search for chessboard corners
        for fname in self.cal_images:
            img = cv2.imread(fname)
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            # Find the chessboard corners
            ret, corners = cv2.findChessboardCorners(gray, (9, 6), None)
#             if not ret: print(fname)
            # If found, add object points, image points
            if ret == True:
                self.objpoints.append(objp)
                self.imgpoints.append(corners)

                # Draw and display the corners
                img = cv2.drawChessboardCorners(img, (9, 6), corners, ret)

    def calibrate_camera(self, test_image):
        img_size = (test_image.shape[1], test_image.shape[0])

        self.set_obj_and_img_points()

        if len(self.objpoints) == 0 or len(self.imgpoints) == 0:
            raise Exception("Calibration Failed!")

        # Do camera calibration given object points and image points
        ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(self.objpoints,
                                                           self.imgpoints,
                                                           img_size,
                                                           None,
                                                           None)

        self.mtx = mtx
        self.dist = dist

    def undistort(self, img):
        return cv2.undistort(img, self.mtx, self.dist, None, self.mtx)

    def to_gray(self, img):
        return cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    def to_rgb(self, img):
        return cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    def abs_sobel_thresh(self, gray, orient='x', thresh_min=40, thresh_max=200, ksize=5):
        # Apply x or y gradient with the OpenCV Sobel() function
        # and take the absolute value
        if orient == 'x':
            abs_sobel = np.absolute(
                cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=ksize))
        if orient == 'y':
            abs_sobel = np.absolute(
                cv2.Sobel(gray, cv2.CV_64F, 0, 1, ksize=ksize))

        # Rescale back to 8 bit integer
        scaled_sobel = np.uint8(255 * abs_sobel / np.max(abs_sobel))

        # Create a copy and apply the threshold
        binary_output = np.zeros_like(scaled_sobel)

        binary_output[(scaled_sobel >= thresh_min) &
                      (scaled_sobel <= thresh_max)] = 1

        # Return the result
        return binary_output

    def mag_thresh(self, gray, thresh_min=40, thresh_max=250, ksize=7):
        # Take both Sobel x and y gradients
        sobelx = cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=ksize)

        sobely = cv2.Sobel(gray, cv2.CV_64F, 0, 1, ksize=ksize)

        # Calculate the gradient magnitude
        gradmag = np.sqrt(sobelx**2 + sobely**2)

        # Rescale to 8 bit
        scale_factor = np.max(gradmag) / 255

        gradmag = (gradmag / scale_factor).astype(np.uint8)

        # Create a binary image of ones where threshold is met, zeros otherwise
        binary_output = np.zeros_like(gradmag)

        binary_output[(gradmag >= thresh_min) & (gradmag <= thresh_max)] = 1

        # Return the binary image
        return binary_output

    def dir_threshold(self, gray, ksize=7, thresh=(0.7, 1.3)):

        # Calculate the x and y gradients
        sobelx = cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=ksize)

        sobely = cv2.Sobel(gray, cv2.CV_64F, 0, 1, ksize=ksize)

        # Take the absolute value of the gradient direction,
        # apply a threshold, and create a binary image result
        absgraddir = np.arctan2(np.absolute(sobely), np.absolute(sobelx))

        binary_output = np.zeros_like(absgraddir)

        binary_output[(absgraddir >= thresh[0]) &
                      (absgraddir <= thresh[1])] = 1

        # Return the binary image
        return binary_output

    def gradient_binary(self, gray, thresh_min=40, thresh_max=250, ksize=7, thresh=(0.7, 1.3)):
        # Apply each of the thresholding functions
        gradx = self.abs_sobel_thresh(gray,
                                      orient='x',
                                      thresh_min=thresh_min,
                                      thresh_max=thresh_max,
                                      ksize=ksize)

        grady = self.abs_sobel_thresh(gray,
                                      orient='y',
                                      thresh_min=thresh_min,
                                      thresh_max=thresh_max,
                                      ksize=ksize)

        mag_binary = self.mag_thresh(gray,
                                     thresh_min=thresh_min,
                                     thresh_max=thresh_max,
                                     ksize=ksize)

        dir_binary = self.dir_threshold(gray, ksize=ksize, thresh=thresh)

        # combine all thresholded images
        combined = np.zeros_like(dir_binary)

        combined[((gradx == 1) & (grady == 1)) | (
            (mag_binary == 1) & (dir_binary == 1))] = 1

        # Return the result
        return combined

    def s_binary(self, img, gradient_binary):
        # Threshold color channel
        s_binary = self.to_hls(img)

        # Stack each channel to view their individual contributions in green and blue respectively
        # This returns a stack of the two binary images, whose components you
        # can see as different colors
        color_binary = np.dstack(
            (np.zeros_like(gradient_binary), gradient_binary, s_binary))

        return color_binary

    def binary_transform(self, img, thresh_min=40, thresh_max=250, ksize=7, thresh=(0.7, 1.3), hls_thresh=(175, 255)):

        gray = self.to_gray(img)

        # Gradient threshold
        gradient_binary = self.gradient_binary(
            gray, thresh_min=thresh_min, thresh_max=thresh_max, ksize=ksize, thresh=thresh)

        # S threshold
        s_binary = self.s_binary(img, gradient_binary)

        # Combine the two binary thresholds
#         combined_binary = np.zeros_like(gradient_binary)
#         combined_binary[(s_binary == 1) | (gradient_binary == 1)] = 1

        # Return the result
        return gradient_binary

    def to_hls(self, img, hls_thresh=(50, 200)):
        hls = cv2.cvtColor(img, cv2.COLOR_BGR2HLS)

        s_channel = hls[:, :, 2]

        binary_output = np.zeros_like(s_channel)

        binary_output[(s_channel > hls_thresh[0]) &
                      (s_channel <= hls_thresh[1])] = 1

        return binary_output

    def perspective_transform(self, binary):
        self.img_size = (binary.shape[1], binary.shape[0])

        self.src = np.float32(
            [[(self.img_size[0] / 2) - 55, self.img_size[1] / 2 + 100],
             [((self.img_size[0] / 6) - 10), self.img_size[1]],
             [(self.img_size[0] * 5 / 6) + 60, self.img_size[1]],
             [(self.img_size[0] / 2 + 55), self.img_size[1] / 2 + 100]])

        self.dst = np.float32(
            [[(self.img_size[0] / 4), 0],
             [(self.img_size[0] / 4), self.img_size[1]],
             [(self.img_size[0] * 3 / 4), self.img_size[1]],
             [(self.img_size[0] * 3 / 4), 0]])

#         self.src = np.float32([
#             [  585., 460.],
#             [  286 , 675.],
#             [ 1005 , 675.],
#             [  695., 460.]])

#         self.dst = np.float32([
#             [ 320.,    0.],
#             [ 320.,  720.],
#             [ 960.,  720.],
#             [ 960.,    0.]])

        # Given src and dst points, calculate the perspective transform matrix
        M = cv2.getPerspectiveTransform(self.src, self.dst)

        # Warp the image using OpenCV warpPerspective()
        return cv2.warpPerspective(binary, M, self.img_size)

    def sliding_windows(self, binary_warped, out_img, leftx_base, rightx_base):
        #
        def slide(window):
            # Identify window boundaries in x and y (and right and left)
            win_y_low = binary_warped.shape[
                0] - (window + 1) * self.window_height

            win_y_high = binary_warped.shape[0] - window * self.window_height

            win_xleft_low = leftx_base - self.margin

            win_xleft_high = leftx_base + self.margin

            win_xright_low = rightx_base - self.margin

            win_xright_high = rightx_base + self.margin

            # Draw the windows on the visualization image
            cv2.rectangle(out_img, (win_xleft_low, win_y_low),
                          (win_xleft_high, win_y_high), (0, 255, 0), 2)

            cv2.rectangle(out_img, (win_xright_low, win_y_low),
                          (win_xright_high, win_y_high), (0, 255, 0), 2)

            # Identify the nonzero pixels in x and y within the window
            good_left_inds = ((nonzeroy >= win_y_low) & (nonzeroy < win_y_high) & (
                nonzerox >= win_xleft_low) & (nonzerox < win_xleft_high)).nonzero()[0]

            good_right_inds = ((nonzeroy >= win_y_low) & (nonzeroy < win_y_high) & (
                nonzerox >= win_xright_low) & (nonzerox < win_xright_high)).nonzero()[0]

            # Append these indices to the lists
            self.left_line.inds.append(good_left_inds)

            self.right_line.inds.append(good_right_inds)

            # If you found > minpix pixels, recenter next window on their mean
            # position
            if len(good_left_inds) > self.minpix:
                leftx_current = np.int(np.mean(nonzerox[good_left_inds]))

            if len(good_right_inds) > self.minpix:
                rightx_current = np.int(np.mean(nonzerox[good_right_inds]))

        # Set height of windows
        self.window_height = np.int(binary_warped.shape[0] / self.nwindows)

        # Identify the x and y positions of all nonzero pixels in the image
        nonzero = binary_warped.nonzero()
        nonzeroy = np.array(nonzero[0])
        nonzerox = np.array(nonzero[1])

        # Current positions to be updated for each window
        leftx_current = leftx_base
        
        rightx_current = rightx_base

        # Create empty lists to receive left and right lane pixel indices
        self.left_line.inds = []
        self.right_line.inds = []

        # Step through the windows one by one
        for window in range(self.nwindows):
            slide(window)

        # Concatenate the arrays of indices
        self.left_line.inds = np.concatenate(self.left_line.inds)

        self.right_line.inds = np.concatenate(self.right_line.inds)

        return nonzeroy, nonzerox

    def set_lane_lines(self, nonzerox, nonzeroy):
        # Again, extract left and right line pixel positions
        self.left_line.x = nonzerox[self.left_line.inds]
        
        self.left_line.y = nonzeroy[self.left_line.inds]
        
        self.right_line.x = nonzerox[self.right_line.inds]
        
        self.right_line.y = nonzeroy[self.right_line.inds]
        
        # Fit a second order polynomial to each
        self.left_line.current_fit = np.polyfit(self.left_line.y, self.left_line.x, 2)
        
        self.right_line.current_fit = np.polyfit(self.right_line.y, self.right_line.x, 2)

        # append polynomia for use in average
        self.left_line.polyfits.append(self.left_line.current_fit)

        self.right_line.polyfits.append(self.right_line.current_fit)

        self.left_line.average_fit()

        self.right_line.average_fit()

        self.radius_to_meters()


    def detect_lines_using_windows(self, binary_warped, orig):
        # Assuming you have created a warped binary image called "binary_warped"
        # Take a histogram of the bottom half of the image
        histogram = np.sum(
            binary_warped[binary_warped.shape[0] / 2:, :], axis=0)

        # Create an output image to draw on and  visualize the result
        out_img = np.dstack(
            (binary_warped, binary_warped, binary_warped)) * 255

        # Find the peak of the left and right halves of the histogram
        # These will be the starting point for the left and right lines
        self.lane_width = self.pix_to_meter * np.int(histogram.shape[0])

        self.midpoint = np.int(histogram.shape[0] / 2)

        leftx_base = np.argmax(histogram[:midpoint])

        rightx_base = np.argmax(histogram[midpoint:]) + midpoint

        self.left_line.line_base_pos = self.distance_to_center_in_meters(
            leftx_base, midpoint)

        self.right_line.line_base_pos = self.distance_to_center_in_meters(
            rightx_base, midpoint)

        nonzeroy, nonzerox = self.sliding_windows(binary_warped, out_img, leftx_base, rightx_base)

        self.set_lane_lines(nonzerox, nonzeroy)

        self.radius_to_meters()

        self.sanity_check(binary_warped, orig)

        return self.project_lane(binary_warped, orig, nonzeroy, nonzerox)

    def radius_to_meters(self):
        y_eval = np.max(self.ploty)

        # Fit new polynomials to x,y in world space
        left_fit_cr = np.polyfit(
            self.left_line.y * self.ym_per_pix, self.left_line.x * self.xm_per_pix, 2)

        right_fit_cr = np.polyfit(
            self.right_line.y * self.ym_per_pix, self.right_line.x * self.xm_per_pix, 2)

        # Calculate the new radii of curvature
        self.left_line.radius_of_curvature = ((1 + (2 * left_fit_cr[0] * y_eval * self.ym_per_pix + left_fit_cr[
            1])**2)**1.5) / np.absolute(2 * left_fit_cr[0])

        self.right_line.radius_of_curvature = ((1 + (2 * right_fit_cr[0] * y_eval * self.ym_per_pix + right_fit_cr[
            1])**2)**1.5) / np.absolute(2 * right_fit_cr[0])

        # Now our radius of curvature is in meters
#         print(left_curverad*3.28084, 'ft', right_curverad*3.28084, 'ft')
#         print(left_curverad, 'm', right_curverad, 'm')
#         Example values: 632.1 m    626.2 m

    def distance_to_center_in_meters(self, x_base, midpoint):
        return abs(x_base - midpoint) * self.pix_to_meter

    def detect_lines_from_previous(self, binary_warped, orig):
        # Assume you now have a new warped binary image
        # from the next frame of video (also called "binary_warped")
        # It's now much easier to find line pixels!
        nonzero = binary_warped.nonzero()
        nonzeroy = np.array(nonzero[0])
        nonzerox = np.array(nonzero[1])

        self.left_line.inds = ((nonzerox >
                           (self.left_line.current_fit[0] * (nonzeroy**2)
                            + self.left_line.current_fit[1] * nonzeroy
                            + self.left_line.current_fit[2] - self.margin))
                          & (nonzerox < (self.left_line.current_fit[0] * (nonzeroy**2)
                                         + self.left_line.current_fit[1] * nonzeroy
                                         + self.left_line.current_fit[2] + self.margin)))

        self.right_line.inds = ((nonzerox > (self.right_line.current_fit[0] * (nonzeroy**2)
                                        + self.right_line.current_fit[1] * nonzeroy
                                        + self.right_line.current_fit[2] - self.margin))
                           & (nonzerox < (self.right_line.current_fit[0] * (nonzeroy**2)
                                          + self.right_line.current_fit[1] * nonzeroy
                                          + self.right_line.current_fit[2] + self.margin)))

        self.set_lane_lines(nonzerox, nonzeroy)

        self.sanity_check(binary_warped, orig, prev=True)

        return self.project_lane(binary_warped, orig, nonzeroy, nonzerox)
        

    def sanity_check(self, binary_warped, orig, prev=False):
        # check that lines are roughly parrellel
        parrellel = True
        center = True
        
        if abs(self.left_line.radius_of_curvature - self.right_line.radius_of_curvature) > 300:
            parrellel = False

        if (self.left_line.line_base_pos + self.left_line.line_base_pos) < self.lane_width:
            center = False

        if center and parrellel:
            self.bad_count = 0
            return

        if self.bad_count > 3:
            print(self.bad_count, 'on frame', self.count, ' .... ', 'reverting to windows')
            self.bad_count = 0

            self.detect_lines_using_windows(binary_warped, orig)

        if prev and not center and not parrellel:
            print(self.bad_count, 'on frame', self.count)
            self.bad_count += 1

            self.left_lane.current_fit = self.left_lane.polyfits[self.count-self.bad_count]

            self.right_lane.current_fit = self.right_lane.polyfits[self.count-self.bad_count]

            self.detect_lines_from_previous(binary_warped, orig)

    def project_lane(self, binary_warped, orig, nonzeroy, nonzerox):

        left_fitx = self.left_line.current_fit[0] \
            * self.ploty**2 + self.left_line.current_fit[1] \
            * self.ploty + self.left_line.current_fit[2]

        right_fitx = self.right_line.current_fit[0] \
            * self.ploty**2 + self.right_line.current_fit[1] \
            * self.ploty + self.right_line.current_fit[2]

        # Create an image to draw on and an image to show the selection window
        out_img = np.dstack(
            (binary_warped, binary_warped, binary_warped)) * 255

        window_img = np.zeros_like(out_img)

        # Color in left and right line pixels
        out_img[nonzeroy[self.left_line.inds], nonzerox[
            self.left_line.inds]] = [255, 0, 0]
        out_img[nonzeroy[self.right_line.inds], nonzerox[
            self.right_line.inds]] = [0, 0, 255]

        # Generate a polygon to illustrate the search window area
        # And recast the x and y points into usable format for cv2.fillPoly()
        left_line_window1 = np.array(
            [np.transpose(np.vstack([left_fitx - self.margin, self.ploty]))])
        left_line_window2 = np.array(
            [np.flipud(np.transpose(np.vstack([left_fitx + self.margin, self.ploty])))])
        left_line_pts = np.hstack((left_line_window1, left_line_window2))

        right_line_window1 = np.array(
            [np.transpose(np.vstack([right_fitx - self.margin, self.ploty]))])
        right_line_window2 = np.array(
            [np.flipud(np.transpose(np.vstack([right_fitx + self.margin, self.ploty])))])
        right_line_pts = np.hstack((right_line_window1, right_line_window2))

        # Create an image to draw the lines on
        warp_zero = np.zeros_like(binary_warped).astype(np.uint8)
        color_warp = np.dstack((warp_zero, warp_zero, warp_zero))

        # Recast the x and y points into usable format for cv2.fillPoly()
        pts_left = np.array([np.transpose(np.vstack([left_fitx, self.ploty]))])
        pts_right = np.array(
            [np.flipud(np.transpose(np.vstack([right_fitx, self.ploty])))])
        pts = np.hstack((pts_left, pts_right))

        # Draw the lane onto the warped blank image
        cv2.fillPoly(color_warp, np.int_([pts]), (0, 255, 0))

        Minv = cv2.getPerspectiveTransform(self.dst, self.src)

        # Warp the blank back to original image space using inverse perspective
        # matrix (Minv)
        newwarp = cv2.warpPerspective(color_warp, Minv, self.img_size)
        # Combine the result with the original image
        result = cv2.addWeighted(orig, 1, newwarp, 0.3, 0)
        # plt.imshow(self.to_rgb(result))

        cv2.imwrite(
            './output_images/lanes_detected{}.jpg'.format(self.count), result)

        # self.writer.write(result)
        return result

    def process_image(self, img):
        self.count += 1
        self.bad_count = 0

        binary = ld.binary_transform(ld.undistort(
            img), thresh_min=40, thresh_max=200, ksize=3, thresh=(0.7, 1.3), hls_thresh=(175, 255))

        binary_warped = ld.perspective_transform(binary)

        # Generate x and y values for plotting
        self.ploty = np.linspace(0, binary_warped.shape[
                            0] - 1, binary_warped.shape[0])

        if self.left_line.detected and self.right_line.detected:
            return self.detect_lines_from_previous(binary_warped, img)

        return self.detect_lines_using_windows(binary_warped, img)

# %%
images = glob.glob('camera_cal/calibration*.jpg')
# use one image as calibration
test_image = images.pop(-1)

# create instance of LaneDetection class
ld = LaneDetection(images, test_image,
                       'project_video.mp4', 'output_video.mp4')

# %%
img = ld.process_image(cv2.imread('project_video_export/frame552.jpg'))
# type(img)
plt.imshow(img)

# %%
img = ld.process_image(cv2.imread('project_video_export/frame625.jpg'))
# type(img)
plt.imshow(img)

# %%
print(abs(ld.left_line.line_base_pos - ld.right_line.line_base_pos))

# %%
import re

def atoi(text):
    return int(text) if text.isdigit() else text

def natural_keys(text):
    '''
    alist.sort(key=natural_keys) sorts in human order
    http://nedbatchelder.com/blog/200712/human_sorting.html
    (See Toothy's implementation in the comments)
    '''
    return [ atoi(c) for c in re.split('(\d+)', text) ]

# %%
alist = glob.glob('./project_video_export/*.jpg')
alist.sort(key=natural_keys)

# %%
images = glob.glob('camera_cal/calibration*.jpg')
# use one image as calibration
test_image = images.pop(-1)

# create instance of LaneDetection class
ld = LaneDetection(images, test_image,
                       'project_video.mp4', 'output_video.mp4')

# %%
for img in alist:
    print('processing', img)
    ld.process_image(cv2.imread(img))
# Out:
# processing ./project_video_export/frame0.jpg
# processing ./project_video_export/frame1.jpg
# processing ./project_video_export/frame2.jpg
# processing ./project_video_export/frame3.jpg
# processing ./project_video_export/frame4.jpg
# processing ./project_video_export/frame5.jpg
# processing ./project_video_export/frame6.jpg
# processing ./project_video_export/frame7.jpg
# processing ./project_video_export/frame8.jpg
# processing ./project_video_export/frame9.jpg
# processing ./project_video_export/frame10.jpg
# processing ./project_video_export/frame11.jpg
# processing ./project_video_export/frame12.jpg
# processing ./project_video_export/frame13.jpg
# processing ./project_video_export/frame14.jpg
# processing ./project_video_export/frame15.jpg
# processing ./project_video_export/frame16.jpg
# processing ./project_video_export/frame17.jpg
# processing ./project_video_export/frame18.jpg
# processing ./project_video_export/frame19.jpg
# processing ./project_video_export/frame20.jpg
# processing ./project_video_export/frame21.jpg
# processing ./project_video_export/frame22.jpg
# processing ./project_video_export/frame23.jpg
# processing ./project_video_export/frame24.jpg
# processing ./project_video_export/frame25.jpg
# processing ./project_video_export/frame26.jpg
# processing ./project_video_export/frame27.jpg
# processing ./project_video_export/frame28.jpg
# processing ./project_video_export/frame29.jpg
# processing ./project_video_export/frame30.jpg
# processing ./project_video_export/frame31.jpg
# processing ./project_video_export/frame32.jpg
# processing ./project_video_export/frame33.jpg
# processing ./project_video_export/frame34.jpg
# processing ./project_video_export/frame35.jpg
# processing ./project_video_export/frame36.jpg
# processing ./project_video_export/frame37.jpg
# processing ./project_video_export/frame38.jpg
# processing ./project_video_export/frame39.jpg
# processing ./project_video_export/frame40.jpg
# processing ./project_video_export/frame41.jpg
# processing ./project_video_export/frame42.jpg
# processing ./project_video_export/frame43.jpg
# processing ./project_video_export/frame44.jpg
# processing ./project_video_export/frame45.jpg
# processing ./project_video_export/frame46.jpg
# processing ./project_video_export/frame47.jpg
# processing ./project_video_export/frame48.jpg
# processing ./project_video_export/frame49.jpg
# processing ./project_video_export/frame50.jpg
# processing ./project_video_export/frame51.jpg
# processing ./project_video_export/frame52.jpg
# processing ./project_video_export/frame53.jpg
# processing ./project_video_export/frame54.jpg
# processing ./project_video_export/frame55.jpg
# processing ./project_video_export/frame56.jpg
# processing ./project_video_export/frame57.jpg
# processing ./project_video_export/frame58.jpg
# processing ./project_video_export/frame59.jpg
# processing ./project_video_export/frame60.jpg
# processing ./project_video_export/frame61.jpg
# processing ./project_video_export/frame62.jpg
# processing ./project_video_export/frame63.jpg
# processing ./project_video_export/frame64.jpg
# processing ./project_video_export/frame65.jpg
# processing ./project_video_export/frame66.jpg
# processing ./project_video_export/frame67.jpg
# processing ./project_video_export/frame68.jpg
# processing ./project_video_export/frame69.jpg
# processing ./project_video_export/frame70.jpg
# processing ./project_video_export/frame71.jpg
# processing ./project_video_export/frame72.jpg
# processing ./project_video_export/frame73.jpg
# processing ./project_video_export/frame74.jpg
# processing ./project_video_export/frame75.jpg
# processing ./project_video_export/frame76.jpg
# processing ./project_video_export/frame77.jpg
# processing ./project_video_export/frame78.jpg
# processing ./project_video_export/frame79.jpg
# processing ./project_video_export/frame80.jpg
# processing ./project_video_export/frame81.jpg
# processing ./project_video_export/frame82.jpg
# processing ./project_video_export/frame83.jpg
# processing ./project_video_export/frame84.jpg
# processing ./project_video_export/frame85.jpg
# processing ./project_video_export/frame86.jpg
# processing ./project_video_export/frame87.jpg
# processing ./project_video_export/frame88.jpg
# processing ./project_video_export/frame89.jpg
# processing ./project_video_export/frame90.jpg
# processing ./project_video_export/frame91.jpg
# processing ./project_video_export/frame92.jpg
# processing ./project_video_export/frame93.jpg
# processing ./project_video_export/frame94.jpg
# processing ./project_video_export/frame95.jpg
# processing ./project_video_export/frame96.jpg
# processing ./project_video_export/frame97.jpg
# processing ./project_video_export/frame98.jpg
# processing ./project_video_export/frame99.jpg
# processing ./project_video_export/frame100.jpg
# processing ./project_video_export/frame101.jpg
# processing ./project_video_export/frame102.jpg
# processing ./project_video_export/frame103.jpg
# processing ./project_video_export/frame104.jpg
# processing ./project_video_export/frame105.jpg
# processing ./project_video_export/frame106.jpg
# processing ./project_video_export/frame107.jpg
# processing ./project_video_export/frame108.jpg
# processing ./project_video_export/frame109.jpg
# processing ./project_video_export/frame110.jpg
# processing ./project_video_export/frame111.jpg
# processing ./project_video_export/frame112.jpg
# processing ./project_video_export/frame113.jpg
# processing ./project_video_export/frame114.jpg
# processing ./project_video_export/frame115.jpg
# processing ./project_video_export/frame116.jpg
# processing ./project_video_export/frame117.jpg
# processing ./project_video_export/frame118.jpg
# processing ./project_video_export/frame119.jpg
# processing ./project_video_export/frame120.jpg
# processing ./project_video_export/frame121.jpg
# processing ./project_video_export/frame122.jpg
# processing ./project_video_export/frame123.jpg
# processing ./project_video_export/frame124.jpg
# processing ./project_video_export/frame125.jpg
# processing ./project_video_export/frame126.jpg
# processing ./project_video_export/frame127.jpg
# processing ./project_video_export/frame128.jpg
# processing ./project_video_export/frame129.jpg
# processing ./project_video_export/frame130.jpg
# processing ./project_video_export/frame131.jpg
# processing ./project_video_export/frame132.jpg
# processing ./project_video_export/frame133.jpg
# processing ./project_video_export/frame134.jpg
# processing ./project_video_export/frame135.jpg
# processing ./project_video_export/frame136.jpg
# processing ./project_video_export/frame137.jpg
# processing ./project_video_export/frame138.jpg
# processing ./project_video_export/frame139.jpg
# processing ./project_video_export/frame140.jpg
# processing ./project_video_export/frame141.jpg
# processing ./project_video_export/frame142.jpg
# processing ./project_video_export/frame143.jpg
# processing ./project_video_export/frame144.jpg
# processing ./project_video_export/frame145.jpg
# processing ./project_video_export/frame146.jpg
# processing ./project_video_export/frame147.jpg
# processing ./project_video_export/frame148.jpg
# processing ./project_video_export/frame149.jpg
# processing ./project_video_export/frame150.jpg
# processing ./project_video_export/frame151.jpg
# processing ./project_video_export/frame152.jpg
# processing ./project_video_export/frame153.jpg
# processing ./project_video_export/frame154.jpg
# processing ./project_video_export/frame155.jpg
# processing ./project_video_export/frame156.jpg
# processing ./project_video_export/frame157.jpg
# processing ./project_video_export/frame158.jpg
# processing ./project_video_export/frame159.jpg
# processing ./project_video_export/frame160.jpg
# processing ./project_video_export/frame161.jpg
# processing ./project_video_export/frame162.jpg
# processing ./project_video_export/frame163.jpg
# processing ./project_video_export/frame164.jpg
# processing ./project_video_export/frame165.jpg
# processing ./project_video_export/frame166.jpg
# processing ./project_video_export/frame167.jpg
# processing ./project_video_export/frame168.jpg
# processing ./project_video_export/frame169.jpg
# processing ./project_video_export/frame170.jpg
# processing ./project_video_export/frame171.jpg
# processing ./project_video_export/frame172.jpg
# processing ./project_video_export/frame173.jpg
# processing ./project_video_export/frame174.jpg
# processing ./project_video_export/frame175.jpg
# processing ./project_video_export/frame176.jpg
# processing ./project_video_export/frame177.jpg
# processing ./project_video_export/frame178.jpg
# processing ./project_video_export/frame179.jpg
# processing ./project_video_export/frame180.jpg
# processing ./project_video_export/frame181.jpg
# processing ./project_video_export/frame182.jpg
# processing ./project_video_export/frame183.jpg
# processing ./project_video_export/frame184.jpg
# processing ./project_video_export/frame185.jpg
# processing ./project_video_export/frame186.jpg
# processing ./project_video_export/frame187.jpg
# processing ./project_video_export/frame188.jpg
# processing ./project_video_export/frame189.jpg
# processing ./project_video_export/frame190.jpg
# processing ./project_video_export/frame191.jpg
# processing ./project_video_export/frame192.jpg
# processing ./project_video_export/frame193.jpg
# processing ./project_video_export/frame194.jpg
# processing ./project_video_export/frame195.jpg
# processing ./project_video_export/frame196.jpg
# processing ./project_video_export/frame197.jpg
# processing ./project_video_export/frame198.jpg
# processing ./project_video_export/frame199.jpg
# processing ./project_video_export/frame200.jpg
# processing ./project_video_export/frame201.jpg
# processing ./project_video_export/frame202.jpg
# processing ./project_video_export/frame203.jpg
# processing ./project_video_export/frame204.jpg
# processing ./project_video_export/frame205.jpg
# processing ./project_video_export/frame206.jpg
# processing ./project_video_export/frame207.jpg
# processing ./project_video_export/frame208.jpg
# processing ./project_video_export/frame209.jpg
# processing ./project_video_export/frame210.jpg
# processing ./project_video_export/frame211.jpg
# processing ./project_video_export/frame212.jpg
# processing ./project_video_export/frame213.jpg
# processing ./project_video_export/frame214.jpg
# processing ./project_video_export/frame215.jpg
# processing ./project_video_export/frame216.jpg
# processing ./project_video_export/frame217.jpg
# processing ./project_video_export/frame218.jpg
# processing ./project_video_export/frame219.jpg
# processing ./project_video_export/frame220.jpg
# processing ./project_video_export/frame221.jpg
# processing ./project_video_export/frame222.jpg
# processing ./project_video_export/frame223.jpg
# processing ./project_video_export/frame224.jpg
# processing ./project_video_export/frame225.jpg
# processing ./project_video_export/frame226.jpg
# processing ./project_video_export/frame227.jpg
# processing ./project_video_export/frame228.jpg
# processing ./project_video_export/frame229.jpg
# processing ./project_video_export/frame230.jpg
# processing ./project_video_export/frame231.jpg
# processing ./project_video_export/frame232.jpg
# processing ./project_video_export/frame233.jpg
# processing ./project_video_export/frame234.jpg
# processing ./project_video_export/frame235.jpg
# processing ./project_video_export/frame236.jpg
# processing ./project_video_export/frame237.jpg
# processing ./project_video_export/frame238.jpg
# processing ./project_video_export/frame239.jpg
# processing ./project_video_export/frame240.jpg
# processing ./project_video_export/frame241.jpg
# processing ./project_video_export/frame242.jpg
# processing ./project_video_export/frame243.jpg
# processing ./project_video_export/frame244.jpg
# processing ./project_video_export/frame245.jpg
# processing ./project_video_export/frame246.jpg
# processing ./project_video_export/frame247.jpg
# processing ./project_video_export/frame248.jpg
# processing ./project_video_export/frame249.jpg
# processing ./project_video_export/frame250.jpg
# processing ./project_video_export/frame251.jpg
# processing ./project_video_export/frame252.jpg
# processing ./project_video_export/frame253.jpg
# processing ./project_video_export/frame254.jpg
# processing ./project_video_export/frame255.jpg
# processing ./project_video_export/frame256.jpg
# processing ./project_video_export/frame257.jpg
# processing ./project_video_export/frame258.jpg
# processing ./project_video_export/frame259.jpg
# processing ./project_video_export/frame260.jpg
# processing ./project_video_export/frame261.jpg
# processing ./project_video_export/frame262.jpg
# processing ./project_video_export/frame263.jpg
# processing ./project_video_export/frame264.jpg
# processing ./project_video_export/frame265.jpg
# processing ./project_video_export/frame266.jpg
# processing ./project_video_export/frame267.jpg
# processing ./project_video_export/frame268.jpg
# processing ./project_video_export/frame269.jpg
# processing ./project_video_export/frame270.jpg
# processing ./project_video_export/frame271.jpg
# processing ./project_video_export/frame272.jpg
# processing ./project_video_export/frame273.jpg
# processing ./project_video_export/frame274.jpg
# processing ./project_video_export/frame275.jpg
# processing ./project_video_export/frame276.jpg
# processing ./project_video_export/frame277.jpg
# processing ./project_video_export/frame278.jpg
# processing ./project_video_export/frame279.jpg
# processing ./project_video_export/frame280.jpg
# processing ./project_video_export/frame281.jpg
# processing ./project_video_export/frame282.jpg
# processing ./project_video_export/frame283.jpg
# processing ./project_video_export/frame284.jpg
# processing ./project_video_export/frame285.jpg
# processing ./project_video_export/frame286.jpg
# processing ./project_video_export/frame287.jpg
# processing ./project_video_export/frame288.jpg
# processing ./project_video_export/frame289.jpg
# processing ./project_video_export/frame290.jpg
# processing ./project_video_export/frame291.jpg
# processing ./project_video_export/frame292.jpg
# processing ./project_video_export/frame293.jpg
# processing ./project_video_export/frame294.jpg
# processing ./project_video_export/frame295.jpg
# processing ./project_video_export/frame296.jpg
# processing ./project_video_export/frame297.jpg
# processing ./project_video_export/frame298.jpg
# processing ./project_video_export/frame299.jpg
# processing ./project_video_export/frame300.jpg
# processing ./project_video_export/frame301.jpg
# processing ./project_video_export/frame302.jpg
# processing ./project_video_export/frame303.jpg
# processing ./project_video_export/frame304.jpg
# processing ./project_video_export/frame305.jpg
# processing ./project_video_export/frame306.jpg
# processing ./project_video_export/frame307.jpg
# processing ./project_video_export/frame308.jpg
# processing ./project_video_export/frame309.jpg
# processing ./project_video_export/frame310.jpg
# processing ./project_video_export/frame311.jpg
# processing ./project_video_export/frame312.jpg
# processing ./project_video_export/frame313.jpg
# processing ./project_video_export/frame314.jpg
# processing ./project_video_export/frame315.jpg
# processing ./project_video_export/frame316.jpg
# processing ./project_video_export/frame317.jpg
# processing ./project_video_export/frame318.jpg
# processing ./project_video_export/frame319.jpg
# processing ./project_video_export/frame320.jpg
# processing ./project_video_export/frame321.jpg
# processing ./project_video_export/frame322.jpg
# processing ./project_video_export/frame323.jpg
# processing ./project_video_export/frame324.jpg
# processing ./project_video_export/frame325.jpg
# processing ./project_video_export/frame326.jpg
# processing ./project_video_export/frame327.jpg
# processing ./project_video_export/frame328.jpg
# processing ./project_video_export/frame329.jpg
# processing ./project_video_export/frame330.jpg
# processing ./project_video_export/frame331.jpg
# processing ./project_video_export/frame332.jpg
# processing ./project_video_export/frame333.jpg
# processing ./project_video_export/frame334.jpg
# processing ./project_video_export/frame335.jpg
# processing ./project_video_export/frame336.jpg
# processing ./project_video_export/frame337.jpg
# processing ./project_video_export/frame338.jpg
# processing ./project_video_export/frame339.jpg
# processing ./project_video_export/frame340.jpg
# processing ./project_video_export/frame341.jpg
# processing ./project_video_export/frame342.jpg
# processing ./project_video_export/frame343.jpg
# processing ./project_video_export/frame344.jpg
# processing ./project_video_export/frame345.jpg
# processing ./project_video_export/frame346.jpg
# processing ./project_video_export/frame347.jpg
# processing ./project_video_export/frame348.jpg
# processing ./project_video_export/frame349.jpg
# processing ./project_video_export/frame350.jpg
# processing ./project_video_export/frame351.jpg
# processing ./project_video_export/frame352.jpg
# processing ./project_video_export/frame353.jpg
# processing ./project_video_export/frame354.jpg
# processing ./project_video_export/frame355.jpg
# processing ./project_video_export/frame356.jpg
# processing ./project_video_export/frame357.jpg
# processing ./project_video_export/frame358.jpg
# processing ./project_video_export/frame359.jpg
# processing ./project_video_export/frame360.jpg
# processing ./project_video_export/frame361.jpg
# processing ./project_video_export/frame362.jpg
# processing ./project_video_export/frame363.jpg
# processing ./project_video_export/frame364.jpg
# processing ./project_video_export/frame365.jpg
# processing ./project_video_export/frame366.jpg
# processing ./project_video_export/frame367.jpg
# processing ./project_video_export/frame368.jpg
# processing ./project_video_export/frame369.jpg
# processing ./project_video_export/frame370.jpg
# processing ./project_video_export/frame371.jpg
# processing ./project_video_export/frame372.jpg
# processing ./project_video_export/frame373.jpg
# processing ./project_video_export/frame374.jpg
# processing ./project_video_export/frame375.jpg
# processing ./project_video_export/frame376.jpg
# processing ./project_video_export/frame377.jpg
# processing ./project_video_export/frame378.jpg
# processing ./project_video_export/frame379.jpg
# processing ./project_video_export/frame380.jpg
# processing ./project_video_export/frame381.jpg
# processing ./project_video_export/frame382.jpg
# processing ./project_video_export/frame383.jpg
# processing ./project_video_export/frame384.jpg
# processing ./project_video_export/frame385.jpg
# processing ./project_video_export/frame386.jpg
# processing ./project_video_export/frame387.jpg
# processing ./project_video_export/frame388.jpg
# processing ./project_video_export/frame389.jpg
# processing ./project_video_export/frame390.jpg
# processing ./project_video_export/frame391.jpg
# processing ./project_video_export/frame392.jpg
# processing ./project_video_export/frame393.jpg
# processing ./project_video_export/frame394.jpg
# processing ./project_video_export/frame395.jpg
# processing ./project_video_export/frame396.jpg
# processing ./project_video_export/frame397.jpg
# processing ./project_video_export/frame398.jpg
# processing ./project_video_export/frame399.jpg
# processing ./project_video_export/frame400.jpg
# processing ./project_video_export/frame401.jpg
# processing ./project_video_export/frame402.jpg
# processing ./project_video_export/frame403.jpg
# processing ./project_video_export/frame404.jpg
# processing ./project_video_export/frame405.jpg
# processing ./project_video_export/frame406.jpg
# processing ./project_video_export/frame407.jpg
# processing ./project_video_export/frame408.jpg
# processing ./project_video_export/frame409.jpg
# processing ./project_video_export/frame410.jpg
# processing ./project_video_export/frame411.jpg
# processing ./project_video_export/frame412.jpg
# processing ./project_video_export/frame413.jpg
# processing ./project_video_export/frame414.jpg
# processing ./project_video_export/frame415.jpg
# processing ./project_video_export/frame416.jpg
# processing ./project_video_export/frame417.jpg
# processing ./project_video_export/frame418.jpg
# processing ./project_video_export/frame419.jpg
# processing ./project_video_export/frame420.jpg
# processing ./project_video_export/frame421.jpg
# processing ./project_video_export/frame422.jpg
# processing ./project_video_export/frame423.jpg
# processing ./project_video_export/frame424.jpg
# processing ./project_video_export/frame425.jpg
# processing ./project_video_export/frame426.jpg
# processing ./project_video_export/frame427.jpg
# processing ./project_video_export/frame428.jpg
# processing ./project_video_export/frame429.jpg
# processing ./project_video_export/frame430.jpg
# processing ./project_video_export/frame431.jpg
# processing ./project_video_export/frame432.jpg
# processing ./project_video_export/frame433.jpg
# processing ./project_video_export/frame434.jpg
# processing ./project_video_export/frame435.jpg
# processing ./project_video_export/frame436.jpg
# processing ./project_video_export/frame437.jpg
# processing ./project_video_export/frame438.jpg
# processing ./project_video_export/frame439.jpg
# processing ./project_video_export/frame440.jpg
# processing ./project_video_export/frame441.jpg
# processing ./project_video_export/frame442.jpg
# processing ./project_video_export/frame443.jpg
# processing ./project_video_export/frame444.jpg
# processing ./project_video_export/frame445.jpg
# processing ./project_video_export/frame446.jpg
# processing ./project_video_export/frame447.jpg
# processing ./project_video_export/frame448.jpg
# processing ./project_video_export/frame449.jpg
# processing ./project_video_export/frame450.jpg
# processing ./project_video_export/frame451.jpg
# processing ./project_video_export/frame452.jpg
# processing ./project_video_export/frame453.jpg
# processing ./project_video_export/frame454.jpg
# processing ./project_video_export/frame455.jpg
# processing ./project_video_export/frame456.jpg
# processing ./project_video_export/frame457.jpg
# processing ./project_video_export/frame458.jpg
# processing ./project_video_export/frame459.jpg
# processing ./project_video_export/frame460.jpg
# processing ./project_video_export/frame461.jpg
# processing ./project_video_export/frame462.jpg
# processing ./project_video_export/frame463.jpg
# processing ./project_video_export/frame464.jpg
# processing ./project_video_export/frame465.jpg
# processing ./project_video_export/frame466.jpg
# processing ./project_video_export/frame467.jpg
# processing ./project_video_export/frame468.jpg
# processing ./project_video_export/frame469.jpg
# processing ./project_video_export/frame470.jpg
# processing ./project_video_export/frame471.jpg
# processing ./project_video_export/frame472.jpg
# processing ./project_video_export/frame473.jpg
# processing ./project_video_export/frame474.jpg
# processing ./project_video_export/frame475.jpg
# processing ./project_video_export/frame476.jpg
# processing ./project_video_export/frame477.jpg
# processing ./project_video_export/frame478.jpg
# processing ./project_video_export/frame479.jpg
# processing ./project_video_export/frame480.jpg
# processing ./project_video_export/frame481.jpg
# processing ./project_video_export/frame482.jpg
# processing ./project_video_export/frame483.jpg
# processing ./project_video_export/frame484.jpg
# processing ./project_video_export/frame485.jpg
# processing ./project_video_export/frame486.jpg
# processing ./project_video_export/frame487.jpg
# processing ./project_video_export/frame488.jpg
# processing ./project_video_export/frame489.jpg
# processing ./project_video_export/frame490.jpg
# processing ./project_video_export/frame491.jpg
# processing ./project_video_export/frame492.jpg
# processing ./project_video_export/frame493.jpg
# processing ./project_video_export/frame494.jpg
# processing ./project_video_export/frame495.jpg
# processing ./project_video_export/frame496.jpg
# processing ./project_video_export/frame497.jpg
# processing ./project_video_export/frame498.jpg
# processing ./project_video_export/frame499.jpg
# processing ./project_video_export/frame500.jpg
# processing ./project_video_export/frame501.jpg
# processing ./project_video_export/frame502.jpg
# processing ./project_video_export/frame503.jpg
# processing ./project_video_export/frame504.jpg
# processing ./project_video_export/frame505.jpg
# processing ./project_video_export/frame506.jpg
# processing ./project_video_export/frame507.jpg
# processing ./project_video_export/frame508.jpg
# processing ./project_video_export/frame509.jpg
# processing ./project_video_export/frame510.jpg
# processing ./project_video_export/frame511.jpg
# processing ./project_video_export/frame512.jpg
# processing ./project_video_export/frame513.jpg
# processing ./project_video_export/frame514.jpg
# processing ./project_video_export/frame515.jpg
# processing ./project_video_export/frame516.jpg
# processing ./project_video_export/frame517.jpg
# processing ./project_video_export/frame518.jpg
# processing ./project_video_export/frame519.jpg
# processing ./project_video_export/frame520.jpg
# processing ./project_video_export/frame521.jpg
# processing ./project_video_export/frame522.jpg
# processing ./project_video_export/frame523.jpg
# processing ./project_video_export/frame524.jpg
# processing ./project_video_export/frame525.jpg
# processing ./project_video_export/frame526.jpg
# processing ./project_video_export/frame527.jpg
# processing ./project_video_export/frame528.jpg
# processing ./project_video_export/frame529.jpg
# processing ./project_video_export/frame530.jpg
# processing ./project_video_export/frame531.jpg
# processing ./project_video_export/frame532.jpg
# processing ./project_video_export/frame533.jpg
# processing ./project_video_export/frame534.jpg
# processing ./project_video_export/frame535.jpg
# processing ./project_video_export/frame536.jpg
# processing ./project_video_export/frame537.jpg
# processing ./project_video_export/frame538.jpg
# processing ./project_video_export/frame539.jpg
# processing ./project_video_export/frame540.jpg
# processing ./project_video_export/frame541.jpg
# processing ./project_video_export/frame542.jpg
# processing ./project_video_export/frame543.jpg
# processing ./project_video_export/frame544.jpg
# processing ./project_video_export/frame545.jpg
# processing ./project_video_export/frame546.jpg
# processing ./project_video_export/frame547.jpg
# processing ./project_video_export/frame548.jpg
# processing ./project_video_export/frame549.jpg
# processing ./project_video_export/frame550.jpg
# processing ./project_video_export/frame551.jpg
# processing ./project_video_export/frame552.jpg
# processing ./project_video_export/frame553.jpg
# processing ./project_video_export/frame554.jpg
# processing ./project_video_export/frame555.jpg
# processing ./project_video_export/frame556.jpg
# processing ./project_video_export/frame557.jpg
# processing ./project_video_export/frame558.jpg
# processing ./project_video_export/frame559.jpg
# processing ./project_video_export/frame560.jpg
# processing ./project_video_export/frame561.jpg
# processing ./project_video_export/frame562.jpg
# processing ./project_video_export/frame563.jpg
# processing ./project_video_export/frame564.jpg
# processing ./project_video_export/frame565.jpg
# processing ./project_video_export/frame566.jpg
# processing ./project_video_export/frame567.jpg
# processing ./project_video_export/frame568.jpg
# processing ./project_video_export/frame569.jpg
# processing ./project_video_export/frame570.jpg
# processing ./project_video_export/frame571.jpg
# processing ./project_video_export/frame572.jpg
# processing ./project_video_export/frame573.jpg
# processing ./project_video_export/frame574.jpg
# processing ./project_video_export/frame575.jpg
# processing ./project_video_export/frame576.jpg
# processing ./project_video_export/frame577.jpg
# processing ./project_video_export/frame578.jpg
# processing ./project_video_export/frame579.jpg
# processing ./project_video_export/frame580.jpg
# processing ./project_video_export/frame581.jpg
# processing ./project_video_export/frame582.jpg
# processing ./project_video_export/frame583.jpg
# processing ./project_video_export/frame584.jpg
# processing ./project_video_export/frame585.jpg
# processing ./project_video_export/frame586.jpg
# processing ./project_video_export/frame587.jpg
# processing ./project_video_export/frame588.jpg
# processing ./project_video_export/frame589.jpg
# processing ./project_video_export/frame590.jpg
# processing ./project_video_export/frame591.jpg
# processing ./project_video_export/frame592.jpg
# processing ./project_video_export/frame593.jpg
# processing ./project_video_export/frame594.jpg
# processing ./project_video_export/frame595.jpg
# processing ./project_video_export/frame596.jpg
# processing ./project_video_export/frame597.jpg
# processing ./project_video_export/frame598.jpg
# processing ./project_video_export/frame599.jpg
# processing ./project_video_export/frame600.jpg
# processing ./project_video_export/frame601.jpg
# processing ./project_video_export/frame602.jpg
# processing ./project_video_export/frame603.jpg
# processing ./project_video_export/frame604.jpg
# processing ./project_video_export/frame605.jpg
# processing ./project_video_export/frame606.jpg
# processing ./project_video_export/frame607.jpg
# processing ./project_video_export/frame608.jpg
# processing ./project_video_export/frame609.jpg
# processing ./project_video_export/frame610.jpg
# processing ./project_video_export/frame611.jpg
# processing ./project_video_export/frame612.jpg
# processing ./project_video_export/frame613.jpg
# processing ./project_video_export/frame614.jpg
# processing ./project_video_export/frame615.jpg
# processing ./project_video_export/frame616.jpg
# processing ./project_video_export/frame617.jpg
# processing ./project_video_export/frame618.jpg
# processing ./project_video_export/frame619.jpg
# processing ./project_video_export/frame620.jpg
# processing ./project_video_export/frame621.jpg
# processing ./project_video_export/frame622.jpg
# processing ./project_video_export/frame623.jpg
# processing ./project_video_export/frame624.jpg
# processing ./project_video_export/frame625.jpg
# processing ./project_video_export/frame626.jpg
# processing ./project_video_export/frame627.jpg
# processing ./project_video_export/frame628.jpg
# processing ./project_video_export/frame629.jpg
# processing ./project_video_export/frame630.jpg
# processing ./project_video_export/frame631.jpg
# processing ./project_video_export/frame632.jpg
# processing ./project_video_export/frame633.jpg
# processing ./project_video_export/frame634.jpg
# processing ./project_video_export/frame635.jpg
# processing ./project_video_export/frame636.jpg
# processing ./project_video_export/frame637.jpg
# processing ./project_video_export/frame638.jpg
# processing ./project_video_export/frame639.jpg
# processing ./project_video_export/frame640.jpg
# processing ./project_video_export/frame641.jpg
# processing ./project_video_export/frame642.jpg
# processing ./project_video_export/frame643.jpg
# processing ./project_video_export/frame644.jpg
# processing ./project_video_export/frame645.jpg
# processing ./project_video_export/frame646.jpg
# processing ./project_video_export/frame647.jpg
# processing ./project_video_export/frame648.jpg
# processing ./project_video_export/frame649.jpg
# processing ./project_video_export/frame650.jpg
# processing ./project_video_export/frame651.jpg
# processing ./project_video_export/frame652.jpg
# processing ./project_video_export/frame653.jpg
# processing ./project_video_export/frame654.jpg
# processing ./project_video_export/frame655.jpg
# processing ./project_video_export/frame656.jpg
# processing ./project_video_export/frame657.jpg
# processing ./project_video_export/frame658.jpg
# processing ./project_video_export/frame659.jpg
# processing ./project_video_export/frame660.jpg
# processing ./project_video_export/frame661.jpg
# processing ./project_video_export/frame662.jpg
# processing ./project_video_export/frame663.jpg
# processing ./project_video_export/frame664.jpg
# processing ./project_video_export/frame665.jpg
# processing ./project_video_export/frame666.jpg
# processing ./project_video_export/frame667.jpg
# processing ./project_video_export/frame668.jpg
# processing ./project_video_export/frame669.jpg
# processing ./project_video_export/frame670.jpg
# processing ./project_video_export/frame671.jpg
# processing ./project_video_export/frame672.jpg
# processing ./project_video_export/frame673.jpg
# processing ./project_video_export/frame674.jpg
# processing ./project_video_export/frame675.jpg
# processing ./project_video_export/frame676.jpg
# processing ./project_video_export/frame677.jpg
# processing ./project_video_export/frame678.jpg
# processing ./project_video_export/frame679.jpg
# processing ./project_video_export/frame680.jpg
# processing ./project_video_export/frame681.jpg
# processing ./project_video_export/frame682.jpg
# processing ./project_video_export/frame683.jpg
# processing ./project_video_export/frame684.jpg
# processing ./project_video_export/frame685.jpg
# processing ./project_video_export/frame686.jpg
# processing ./project_video_export/frame687.jpg
# processing ./project_video_export/frame688.jpg
# processing ./project_video_export/frame689.jpg
# processing ./project_video_export/frame690.jpg
# processing ./project_video_export/frame691.jpg
# processing ./project_video_export/frame692.jpg
# processing ./project_video_export/frame693.jpg
# processing ./project_video_export/frame694.jpg
# processing ./project_video_export/frame695.jpg
# processing ./project_video_export/frame696.jpg
# processing ./project_video_export/frame697.jpg
# processing ./project_video_export/frame698.jpg
# processing ./project_video_export/frame699.jpg
# processing ./project_video_export/frame700.jpg
# processing ./project_video_export/frame701.jpg
# processing ./project_video_export/frame702.jpg
# processing ./project_video_export/frame703.jpg
# processing ./project_video_export/frame704.jpg
# processing ./project_video_export/frame705.jpg
# processing ./project_video_export/frame706.jpg
# processing ./project_video_export/frame707.jpg
# processing ./project_video_export/frame708.jpg
# processing ./project_video_export/frame709.jpg
# processing ./project_video_export/frame710.jpg
# processing ./project_video_export/frame711.jpg
# processing ./project_video_export/frame712.jpg
# processing ./project_video_export/frame713.jpg
# processing ./project_video_export/frame714.jpg
# processing ./project_video_export/frame715.jpg
# processing ./project_video_export/frame716.jpg
# processing ./project_video_export/frame717.jpg
# processing ./project_video_export/frame718.jpg
# processing ./project_video_export/frame719.jpg
# processing ./project_video_export/frame720.jpg
# processing ./project_video_export/frame721.jpg
# processing ./project_video_export/frame722.jpg
# processing ./project_video_export/frame723.jpg
# processing ./project_video_export/frame724.jpg
# processing ./project_video_export/frame725.jpg
# processing ./project_video_export/frame726.jpg
# processing ./project_video_export/frame727.jpg
# processing ./project_video_export/frame728.jpg
# processing ./project_video_export/frame729.jpg
# processing ./project_video_export/frame730.jpg
# processing ./project_video_export/frame731.jpg
# processing ./project_video_export/frame732.jpg
# processing ./project_video_export/frame733.jpg
# processing ./project_video_export/frame734.jpg
# processing ./project_video_export/frame735.jpg
# processing ./project_video_export/frame736.jpg
# processing ./project_video_export/frame737.jpg
# processing ./project_video_export/frame738.jpg
# processing ./project_video_export/frame739.jpg
# processing ./project_video_export/frame740.jpg
# processing ./project_video_export/frame741.jpg
# processing ./project_video_export/frame742.jpg
# processing ./project_video_export/frame743.jpg
# processing ./project_video_export/frame744.jpg
# processing ./project_video_export/frame745.jpg
# processing ./project_video_export/frame746.jpg
# processing ./project_video_export/frame747.jpg
# processing ./project_video_export/frame748.jpg
# processing ./project_video_export/frame749.jpg
# processing ./project_video_export/frame750.jpg
# processing ./project_video_export/frame751.jpg
# processing ./project_video_export/frame752.jpg
# processing ./project_video_export/frame753.jpg
# processing ./project_video_export/frame754.jpg
# processing ./project_video_export/frame755.jpg
# processing ./project_video_export/frame756.jpg
# processing ./project_video_export/frame757.jpg
# processing ./project_video_export/frame758.jpg
# processing ./project_video_export/frame759.jpg
# processing ./project_video_export/frame760.jpg
# processing ./project_video_export/frame761.jpg
# processing ./project_video_export/frame762.jpg
# processing ./project_video_export/frame763.jpg
# processing ./project_video_export/frame764.jpg
# processing ./project_video_export/frame765.jpg
# processing ./project_video_export/frame766.jpg
# processing ./project_video_export/frame767.jpg
# processing ./project_video_export/frame768.jpg
# processing ./project_video_export/frame769.jpg
# processing ./project_video_export/frame770.jpg
# processing ./project_video_export/frame771.jpg
# processing ./project_video_export/frame772.jpg
# processing ./project_video_export/frame773.jpg
# processing ./project_video_export/frame774.jpg
# processing ./project_video_export/frame775.jpg
# processing ./project_video_export/frame776.jpg
# processing ./project_video_export/frame777.jpg
# processing ./project_video_export/frame778.jpg
# processing ./project_video_export/frame779.jpg
# processing ./project_video_export/frame780.jpg
# processing ./project_video_export/frame781.jpg
# processing ./project_video_export/frame782.jpg
# processing ./project_video_export/frame783.jpg
# processing ./project_video_export/frame784.jpg
# processing ./project_video_export/frame785.jpg
# processing ./project_video_export/frame786.jpg
# processing ./project_video_export/frame787.jpg
# processing ./project_video_export/frame788.jpg
# processing ./project_video_export/frame789.jpg
# processing ./project_video_export/frame790.jpg
# processing ./project_video_export/frame791.jpg
# processing ./project_video_export/frame792.jpg
# processing ./project_video_export/frame793.jpg
# processing ./project_video_export/frame794.jpg
# processing ./project_video_export/frame795.jpg
# processing ./project_video_export/frame796.jpg
# processing ./project_video_export/frame797.jpg
# processing ./project_video_export/frame798.jpg
# processing ./project_video_export/frame799.jpg
# processing ./project_video_export/frame800.jpg
# processing ./project_video_export/frame801.jpg
# processing ./project_video_export/frame802.jpg
# processing ./project_video_export/frame803.jpg
# processing ./project_video_export/frame804.jpg
# processing ./project_video_export/frame805.jpg
# processing ./project_video_export/frame806.jpg
# processing ./project_video_export/frame807.jpg
# processing ./project_video_export/frame808.jpg
# processing ./project_video_export/frame809.jpg
# processing ./project_video_export/frame810.jpg
# processing ./project_video_export/frame811.jpg
# processing ./project_video_export/frame812.jpg
# processing ./project_video_export/frame813.jpg
# processing ./project_video_export/frame814.jpg
# processing ./project_video_export/frame815.jpg
# processing ./project_video_export/frame816.jpg
# processing ./project_video_export/frame817.jpg
# processing ./project_video_export/frame818.jpg
# processing ./project_video_export/frame819.jpg
# processing ./project_video_export/frame820.jpg
# processing ./project_video_export/frame821.jpg
# processing ./project_video_export/frame822.jpg
# processing ./project_video_export/frame823.jpg
# processing ./project_video_export/frame824.jpg
# processing ./project_video_export/frame825.jpg
# processing ./project_video_export/frame826.jpg
# processing ./project_video_export/frame827.jpg
# processing ./project_video_export/frame828.jpg
# processing ./project_video_export/frame829.jpg
# processing ./project_video_export/frame830.jpg
# processing ./project_video_export/frame831.jpg
# processing ./project_video_export/frame832.jpg
# processing ./project_video_export/frame833.jpg
# processing ./project_video_export/frame834.jpg
# processing ./project_video_export/frame835.jpg
# processing ./project_video_export/frame836.jpg
# processing ./project_video_export/frame837.jpg
# processing ./project_video_export/frame838.jpg
# processing ./project_video_export/frame839.jpg
# processing ./project_video_export/frame840.jpg
# processing ./project_video_export/frame841.jpg
# processing ./project_video_export/frame842.jpg
# processing ./project_video_export/frame843.jpg
# processing ./project_video_export/frame844.jpg
# processing ./project_video_export/frame845.jpg
# processing ./project_video_export/frame846.jpg
# processing ./project_video_export/frame847.jpg
# processing ./project_video_export/frame848.jpg
# processing ./project_video_export/frame849.jpg
# processing ./project_video_export/frame850.jpg
# processing ./project_video_export/frame851.jpg
# processing ./project_video_export/frame852.jpg
# processing ./project_video_export/frame853.jpg
# processing ./project_video_export/frame854.jpg
# processing ./project_video_export/frame855.jpg
# processing ./project_video_export/frame856.jpg
# processing ./project_video_export/frame857.jpg
# processing ./project_video_export/frame858.jpg
# processing ./project_video_export/frame859.jpg
# processing ./project_video_export/frame860.jpg
# processing ./project_video_export/frame861.jpg
# processing ./project_video_export/frame862.jpg
# processing ./project_video_export/frame863.jpg
# processing ./project_video_export/frame864.jpg
# processing ./project_video_export/frame865.jpg
# processing ./project_video_export/frame866.jpg
# processing ./project_video_export/frame867.jpg
# processing ./project_video_export/frame868.jpg
# processing ./project_video_export/frame869.jpg
# processing ./project_video_export/frame870.jpg
# processing ./project_video_export/frame871.jpg
# processing ./project_video_export/frame872.jpg
# processing ./project_video_export/frame873.jpg
# processing ./project_video_export/frame874.jpg
# processing ./project_video_export/frame875.jpg
# processing ./project_video_export/frame876.jpg
# processing ./project_video_export/frame877.jpg
# processing ./project_video_export/frame878.jpg
# processing ./project_video_export/frame879.jpg
# processing ./project_video_export/frame880.jpg
# processing ./project_video_export/frame881.jpg
# processing ./project_video_export/frame882.jpg
# processing ./project_video_export/frame883.jpg
# processing ./project_video_export/frame884.jpg
# processing ./project_video_export/frame885.jpg
# processing ./project_video_export/frame886.jpg
# processing ./project_video_export/frame887.jpg
# processing ./project_video_export/frame888.jpg
# processing ./project_video_export/frame889.jpg
# processing ./project_video_export/frame890.jpg
# processing ./project_video_export/frame891.jpg
# processing ./project_video_export/frame892.jpg
# processing ./project_video_export/frame893.jpg
# processing ./project_video_export/frame894.jpg
# processing ./project_video_export/frame895.jpg
# processing ./project_video_export/frame896.jpg
# processing ./project_video_export/frame897.jpg
# processing ./project_video_export/frame898.jpg
# processing ./project_video_export/frame899.jpg
# processing ./project_video_export/frame900.jpg
# processing ./project_video_export/frame901.jpg
# processing ./project_video_export/frame902.jpg
# processing ./project_video_export/frame903.jpg
# processing ./project_video_export/frame904.jpg
# processing ./project_video_export/frame905.jpg
# processing ./project_video_export/frame906.jpg
# processing ./project_video_export/frame907.jpg
# processing ./project_video_export/frame908.jpg
# processing ./project_video_export/frame909.jpg
# processing ./project_video_export/frame910.jpg
# processing ./project_video_export/frame911.jpg
# processing ./project_video_export/frame912.jpg
# processing ./project_video_export/frame913.jpg
# processing ./project_video_export/frame914.jpg
# processing ./project_video_export/frame915.jpg
# processing ./project_video_export/frame916.jpg
# processing ./project_video_export/frame917.jpg
# processing ./project_video_export/frame918.jpg
# processing ./project_video_export/frame919.jpg
# processing ./project_video_export/frame920.jpg
# processing ./project_video_export/frame921.jpg
# processing ./project_video_export/frame922.jpg
# processing ./project_video_export/frame923.jpg
# processing ./project_video_export/frame924.jpg
# processing ./project_video_export/frame925.jpg
# processing ./project_video_export/frame926.jpg
# processing ./project_video_export/frame927.jpg
# processing ./project_video_export/frame928.jpg
# processing ./project_video_export/frame929.jpg
# processing ./project_video_export/frame930.jpg
# processing ./project_video_export/frame931.jpg
# processing ./project_video_export/frame932.jpg
# processing ./project_video_export/frame933.jpg
# processing ./project_video_export/frame934.jpg
# processing ./project_video_export/frame935.jpg
# processing ./project_video_export/frame936.jpg
# processing ./project_video_export/frame937.jpg
# processing ./project_video_export/frame938.jpg
# processing ./project_video_export/frame939.jpg
# processing ./project_video_export/frame940.jpg
# processing ./project_video_export/frame941.jpg
# processing ./project_video_export/frame942.jpg
# processing ./project_video_export/frame943.jpg
# processing ./project_video_export/frame944.jpg
# processing ./project_video_export/frame945.jpg
# processing ./project_video_export/frame946.jpg
# processing ./project_video_export/frame947.jpg
# processing ./project_video_export/frame948.jpg
# processing ./project_video_export/frame949.jpg
# processing ./project_video_export/frame950.jpg
# processing ./project_video_export/frame951.jpg
# processing ./project_video_export/frame952.jpg
# processing ./project_video_export/frame953.jpg
# processing ./project_video_export/frame954.jpg
# processing ./project_video_export/frame955.jpg
# processing ./project_video_export/frame956.jpg
# processing ./project_video_export/frame957.jpg
# processing ./project_video_export/frame958.jpg
# processing ./project_video_export/frame959.jpg
# processing ./project_video_export/frame960.jpg
# processing ./project_video_export/frame961.jpg
# processing ./project_video_export/frame962.jpg
# processing ./project_video_export/frame963.jpg
# processing ./project_video_export/frame964.jpg
# processing ./project_video_export/frame965.jpg
# processing ./project_video_export/frame966.jpg
# processing ./project_video_export/frame967.jpg
# processing ./project_video_export/frame968.jpg
# processing ./project_video_export/frame969.jpg
# processing ./project_video_export/frame970.jpg
# processing ./project_video_export/frame971.jpg
# processing ./project_video_export/frame972.jpg
# processing ./project_video_export/frame973.jpg
# processing ./project_video_export/frame974.jpg
# processing ./project_video_export/frame975.jpg
# processing ./project_video_export/frame976.jpg
# processing ./project_video_export/frame977.jpg
# processing ./project_video_export/frame978.jpg
# processing ./project_video_export/frame979.jpg
# processing ./project_video_export/frame980.jpg
# processing ./project_video_export/frame981.jpg
# processing ./project_video_export/frame982.jpg
# processing ./project_video_export/frame983.jpg
# processing ./project_video_export/frame984.jpg
# processing ./project_video_export/frame985.jpg
# processing ./project_video_export/frame986.jpg
# processing ./project_video_export/frame987.jpg
# processing ./project_video_export/frame988.jpg
# processing ./project_video_export/frame989.jpg
# processing ./project_video_export/frame990.jpg
# processing ./project_video_export/frame991.jpg
# processing ./project_video_export/frame992.jpg
# processing ./project_video_export/frame993.jpg
# processing ./project_video_export/frame994.jpg
# processing ./project_video_export/frame995.jpg
# processing ./project_video_export/frame996.jpg
# processing ./project_video_export/frame997.jpg
# processing ./project_video_export/frame998.jpg
# processing ./project_video_export/frame999.jpg
# processing ./project_video_export/frame1000.jpg
# processing ./project_video_export/frame1001.jpg
# processing ./project_video_export/frame1002.jpg
# processing ./project_video_export/frame1003.jpg
# processing ./project_video_export/frame1004.jpg
# processing ./project_video_export/frame1005.jpg
# processing ./project_video_export/frame1006.jpg
# processing ./project_video_export/frame1007.jpg
# processing ./project_video_export/frame1008.jpg
# processing ./project_video_export/frame1009.jpg
# processing ./project_video_export/frame1010.jpg
# processing ./project_video_export/frame1011.jpg
# processing ./project_video_export/frame1012.jpg
# processing ./project_video_export/frame1013.jpg
# processing ./project_video_export/frame1014.jpg
# processing ./project_video_export/frame1015.jpg
# processing ./project_video_export/frame1016.jpg
# processing ./project_video_export/frame1017.jpg
# processing ./project_video_export/frame1018.jpg
# processing ./project_video_export/frame1019.jpg
# processing ./project_video_export/frame1020.jpg
# processing ./project_video_export/frame1021.jpg
# processing ./project_video_export/frame1022.jpg
# processing ./project_video_export/frame1023.jpg
# processing ./project_video_export/frame1024.jpg
# processing ./project_video_export/frame1025.jpg
# processing ./project_video_export/frame1026.jpg
# processing ./project_video_export/frame1027.jpg
# processing ./project_video_export/frame1028.jpg
# processing ./project_video_export/frame1029.jpg
# processing ./project_video_export/frame1030.jpg
# processing ./project_video_export/frame1031.jpg
# processing ./project_video_export/frame1032.jpg
# processing ./project_video_export/frame1033.jpg
# processing ./project_video_export/frame1034.jpg
# processing ./project_video_export/frame1035.jpg
# processing ./project_video_export/frame1036.jpg
# processing ./project_video_export/frame1037.jpg
# processing ./project_video_export/frame1038.jpg
# processing ./project_video_export/frame1039.jpg
# processing ./project_video_export/frame1040.jpg
# processing ./project_video_export/frame1041.jpg
# processing ./project_video_export/frame1042.jpg
# processing ./project_video_export/frame1043.jpg
# processing ./project_video_export/frame1044.jpg
# processing ./project_video_export/frame1045.jpg
# processing ./project_video_export/frame1046.jpg
# processing ./project_video_export/frame1047.jpg
# processing ./project_video_export/frame1048.jpg
# processing ./project_video_export/frame1049.jpg
# processing ./project_video_export/frame1050.jpg
# processing ./project_video_export/frame1051.jpg
# processing ./project_video_export/frame1052.jpg
# processing ./project_video_export/frame1053.jpg
# processing ./project_video_export/frame1054.jpg
# processing ./project_video_export/frame1055.jpg
# processing ./project_video_export/frame1056.jpg
# processing ./project_video_export/frame1057.jpg
# processing ./project_video_export/frame1058.jpg
# processing ./project_video_export/frame1059.jpg
# processing ./project_video_export/frame1060.jpg
# processing ./project_video_export/frame1061.jpg
# processing ./project_video_export/frame1062.jpg
# processing ./project_video_export/frame1063.jpg
# processing ./project_video_export/frame1064.jpg
# processing ./project_video_export/frame1065.jpg
# processing ./project_video_export/frame1066.jpg
# processing ./project_video_export/frame1067.jpg
# processing ./project_video_export/frame1068.jpg
# processing ./project_video_export/frame1069.jpg
# processing ./project_video_export/frame1070.jpg
# processing ./project_video_export/frame1071.jpg
# processing ./project_video_export/frame1072.jpg
# processing ./project_video_export/frame1073.jpg
# processing ./project_video_export/frame1074.jpg
# processing ./project_video_export/frame1075.jpg
# processing ./project_video_export/frame1076.jpg
# processing ./project_video_export/frame1077.jpg
# processing ./project_video_export/frame1078.jpg
# processing ./project_video_export/frame1079.jpg
# processing ./project_video_export/frame1080.jpg
# processing ./project_video_export/frame1081.jpg
# processing ./project_video_export/frame1082.jpg
# processing ./project_video_export/frame1083.jpg
# processing ./project_video_export/frame1084.jpg
# processing ./project_video_export/frame1085.jpg
# processing ./project_video_export/frame1086.jpg
# processing ./project_video_export/frame1087.jpg
# processing ./project_video_export/frame1088.jpg
# processing ./project_video_export/frame1089.jpg
# processing ./project_video_export/frame1090.jpg
# processing ./project_video_export/frame1091.jpg
# processing ./project_video_export/frame1092.jpg
# processing ./project_video_export/frame1093.jpg
# processing ./project_video_export/frame1094.jpg
# processing ./project_video_export/frame1095.jpg
# processing ./project_video_export/frame1096.jpg
# processing ./project_video_export/frame1097.jpg
# processing ./project_video_export/frame1098.jpg
# processing ./project_video_export/frame1099.jpg
# processing ./project_video_export/frame1100.jpg
# processing ./project_video_export/frame1101.jpg
# processing ./project_video_export/frame1102.jpg
# processing ./project_video_export/frame1103.jpg
# processing ./project_video_export/frame1104.jpg
# processing ./project_video_export/frame1105.jpg
# processing ./project_video_export/frame1106.jpg
# processing ./project_video_export/frame1107.jpg
# processing ./project_video_export/frame1108.jpg
# processing ./project_video_export/frame1109.jpg
# processing ./project_video_export/frame1110.jpg
# processing ./project_video_export/frame1111.jpg
# processing ./project_video_export/frame1112.jpg
# processing ./project_video_export/frame1113.jpg
# processing ./project_video_export/frame1114.jpg
# processing ./project_video_export/frame1115.jpg
# processing ./project_video_export/frame1116.jpg
# processing ./project_video_export/frame1117.jpg
# processing ./project_video_export/frame1118.jpg
# processing ./project_video_export/frame1119.jpg
# processing ./project_video_export/frame1120.jpg
# processing ./project_video_export/frame1121.jpg
# processing ./project_video_export/frame1122.jpg
# processing ./project_video_export/frame1123.jpg
# processing ./project_video_export/frame1124.jpg
# processing ./project_video_export/frame1125.jpg
# processing ./project_video_export/frame1126.jpg
# processing ./project_video_export/frame1127.jpg
# processing ./project_video_export/frame1128.jpg
# processing ./project_video_export/frame1129.jpg
# processing ./project_video_export/frame1130.jpg
# processing ./project_video_export/frame1131.jpg
# processing ./project_video_export/frame1132.jpg
# processing ./project_video_export/frame1133.jpg
# processing ./project_video_export/frame1134.jpg
# processing ./project_video_export/frame1135.jpg
# processing ./project_video_export/frame1136.jpg
# processing ./project_video_export/frame1137.jpg
# processing ./project_video_export/frame1138.jpg
# processing ./project_video_export/frame1139.jpg
# processing ./project_video_export/frame1140.jpg
# processing ./project_video_export/frame1141.jpg
# processing ./project_video_export/frame1142.jpg
# processing ./project_video_export/frame1143.jpg
# processing ./project_video_export/frame1144.jpg
# processing ./project_video_export/frame1145.jpg
# processing ./project_video_export/frame1146.jpg
# processing ./project_video_export/frame1147.jpg
# processing ./project_video_export/frame1148.jpg
# processing ./project_video_export/frame1149.jpg
# processing ./project_video_export/frame1150.jpg
# processing ./project_video_export/frame1151.jpg
# processing ./project_video_export/frame1152.jpg
# processing ./project_video_export/frame1153.jpg
# processing ./project_video_export/frame1154.jpg
# processing ./project_video_export/frame1155.jpg
# processing ./project_video_export/frame1156.jpg
# processing ./project_video_export/frame1157.jpg
# processing ./project_video_export/frame1158.jpg
# processing ./project_video_export/frame1159.jpg
# processing ./project_video_export/frame1160.jpg
# processing ./project_video_export/frame1161.jpg
# processing ./project_video_export/frame1162.jpg
# processing ./project_video_export/frame1163.jpg
# processing ./project_video_export/frame1164.jpg
# processing ./project_video_export/frame1165.jpg
# processing ./project_video_export/frame1166.jpg
# processing ./project_video_export/frame1167.jpg
# processing ./project_video_export/frame1168.jpg
# processing ./project_video_export/frame1169.jpg
# processing ./project_video_export/frame1170.jpg
# processing ./project_video_export/frame1171.jpg
# processing ./project_video_export/frame1172.jpg
# processing ./project_video_export/frame1173.jpg
# processing ./project_video_export/frame1174.jpg
# processing ./project_video_export/frame1175.jpg
# processing ./project_video_export/frame1176.jpg
# processing ./project_video_export/frame1177.jpg
# processing ./project_video_export/frame1178.jpg
# processing ./project_video_export/frame1179.jpg
# processing ./project_video_export/frame1180.jpg
# processing ./project_video_export/frame1181.jpg
# processing ./project_video_export/frame1182.jpg
# processing ./project_video_export/frame1183.jpg
# processing ./project_video_export/frame1184.jpg
# processing ./project_video_export/frame1185.jpg
# processing ./project_video_export/frame1186.jpg
# processing ./project_video_export/frame1187.jpg
# processing ./project_video_export/frame1188.jpg
# processing ./project_video_export/frame1189.jpg
# processing ./project_video_export/frame1190.jpg
# processing ./project_video_export/frame1191.jpg
# processing ./project_video_export/frame1192.jpg
# processing ./project_video_export/frame1193.jpg
# processing ./project_video_export/frame1194.jpg
# processing ./project_video_export/frame1195.jpg
# processing ./project_video_export/frame1196.jpg
# processing ./project_video_export/frame1197.jpg
# processing ./project_video_export/frame1198.jpg
# processing ./project_video_export/frame1199.jpg
# processing ./project_video_export/frame1200.jpg
# processing ./project_video_export/frame1201.jpg
# processing ./project_video_export/frame1202.jpg
# processing ./project_video_export/frame1203.jpg
# processing ./project_video_export/frame1204.jpg
# processing ./project_video_export/frame1205.jpg
# processing ./project_video_export/frame1206.jpg
# processing ./project_video_export/frame1207.jpg
# processing ./project_video_export/frame1208.jpg
# processing ./project_video_export/frame1209.jpg
# processing ./project_video_export/frame1210.jpg
# processing ./project_video_export/frame1211.jpg
# processing ./project_video_export/frame1212.jpg
# processing ./project_video_export/frame1213.jpg
# processing ./project_video_export/frame1214.jpg
# processing ./project_video_export/frame1215.jpg
# processing ./project_video_export/frame1216.jpg
# processing ./project_video_export/frame1217.jpg
# processing ./project_video_export/frame1218.jpg
# processing ./project_video_export/frame1219.jpg
# processing ./project_video_export/frame1220.jpg
# processing ./project_video_export/frame1221.jpg
# processing ./project_video_export/frame1222.jpg
# processing ./project_video_export/frame1223.jpg
# processing ./project_video_export/frame1224.jpg
# processing ./project_video_export/frame1225.jpg
# processing ./project_video_export/frame1226.jpg
# processing ./project_video_export/frame1227.jpg
# processing ./project_video_export/frame1228.jpg
# processing ./project_video_export/frame1229.jpg
# processing ./project_video_export/frame1230.jpg
# processing ./project_video_export/frame1231.jpg
# processing ./project_video_export/frame1232.jpg
# processing ./project_video_export/frame1233.jpg
# processing ./project_video_export/frame1234.jpg
# processing ./project_video_export/frame1235.jpg
# processing ./project_video_export/frame1236.jpg
# processing ./project_video_export/frame1237.jpg
# processing ./project_video_export/frame1238.jpg
# processing ./project_video_export/frame1239.jpg
# processing ./project_video_export/frame1240.jpg
# processing ./project_video_export/frame1241.jpg
# processing ./project_video_export/frame1242.jpg
# processing ./project_video_export/frame1243.jpg
# processing ./project_video_export/frame1244.jpg
# processing ./project_video_export/frame1245.jpg
# processing ./project_video_export/frame1246.jpg
# processing ./project_video_export/frame1247.jpg
# processing ./project_video_export/frame1248.jpg
# processing ./project_video_export/frame1249.jpg
# processing ./project_video_export/frame1250.jpg
# processing ./project_video_export/frame1251.jpg
# processing ./project_video_export/frame1252.jpg
# processing ./project_video_export/frame1253.jpg
# processing ./project_video_export/frame1254.jpg
# processing ./project_video_export/frame1255.jpg
# processing ./project_video_export/frame1256.jpg
